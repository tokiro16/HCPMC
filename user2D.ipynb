# %%
import hcpmc
import os
factory = hcpmc.particlefactory2D.RoundedSquare(0)
factorystr = "hcpmc.particlefactory2D.RoundedSquare(0)"
init = hcpmc.initializer2D.Expander2D(factory, os.path.abspath('sample0.gsd'))

# %% [markdown]
# # 一、制作原初样品

# %% [markdown]
# 计算机模拟也是要先制作样品再进行测量计算的。一个样品的参数通常由粒子数目，粒子位置，粒子形状，粒子朝向，样品密度，晶格形状等组成。
#
# 原初样品指的是样品的一个单胞，其中只包括一个或几个粒子，拥有粒子形状、粒子朝向、粒子位置、晶格形状等参数。不含体系密度参数。
#
# 粒子的所有参数和盒子的所有参数合起来通常也被称为构型（configuration）。
#
# 目前可以生成的样品类型：Densest（最密堆积）、Square2D（正方晶格）、Slanted2D（斜方晶格）、Triangle2D（三角晶格）。
#
# 流体样品只需密度足够小。运行一段时间后，粒子会自发形成流体。

# %% [markdown]
# #### （一）：生成晶格。普通晶格可以很快由下面代码块生成。

# %%
import hcpmc
import os
import numpy as np

# TODO: set the factory and the initializer
factory = hcpmc.particlefactory2D.RoundedSquare(0)
temp = "sample0.gsd"
init = hcpmc.initializer2D.Square2D(factory, temp)

# NO NEED TO CHANGE THIS
init.create_sample0()
# Out:
# {'type': 'Polygon', 'vertices': [[-0.5, -0.5, 0.0], [-0.5, 0.5, 0.0], [0.5, 0.5, 0.0], [0.5, -0.5, 0.0]], 'rounding_radius': np.float64(0.0)}
# {'type': 'Polygon', 'vertices': [[-0.5, -0.5], [-0.5, 0.5], [0.5, 0.5], [0.5, -0.5]], 'rounding_radius': np.float64(0.0)}
# 'sample0.gsd'

# %% [markdown]
# #### （二）：最密堆积晶格。最密堆积由于需要尝试压缩粒子，需要计算一定时间。并且使用下述不同管道。

# %% [markdown]
# ##### 步骤1：设定粒子形状以及单胞中粒子个数，运行下面代码

# %%
# you may use this code for user-defined shape.
import coxeter
import rowan
import numpy as np
rhombic_dodecahedron = coxeter.families.CatalanFamily.get_shape("Rhombic Dodecahedron")

vertices = rhombic_dodecahedron.vertices

for i in range(len(vertices)):
    vertices[i] = rowan.rotate(
        rowan.from_axis_angle([0, 1, 0], np.arctan(0.56123102 / 0.39685026)),
        vertices[i],
    )

for i in range(len(vertices)):
    if vertices[i][2] < 0:
        vertices[i] = rowan.rotate(rowan.from_axis_angle([0, 0, 1], np.pi / 3), vertices[i])

# %%
# Densest using different pipeline
import hcpmc
import numpy as np

# TODO: set the factory and the initializer
factory = hcpmc.particlefactory2D.RoundedSquare(0)
particle_per_cell = 1
seeds = np.arange(70)
temp = os.path.abspath('sample0.gsd')

init = hcpmc.initializer2D.Densest2D(factory, particle_per_cell, temp, seeds)
# Out:
# /home/jwang/miniforge3/envs/hd5/lib/python3.13/site-packages/synced_collections/numpy_utils.py:43: NumpyConversionWarning: Any numpy types provided will be transparently converted to the closest base Python equivalents.
#   warnings.warn(NUMPY_CONVERSION_WARNING, NumpyConversionWarning)
# /home/jwang/miniforge3/envs/hd5/lib/python3.13/site-packages/synced_collections/numpy_utils.py:46: NumpyConversionWarning: Any numpy types provided will be transparently converted to the closest base Python equivalents.
#   warnings.warn(NUMPY_CONVERSION_WARNING, NumpyConversionWarning)

# %% [markdown]
# ##### 步骤2：发送命令开始压缩体系，复制最后两行代码到终端中执行可以查看运行进程。

# %%
init.compress()
# Out:
# Output:
# Error: Querying scheduler...
# Submitting cluster job 'Densest/24cd24d8903b718fb75b05c460a01fcb/compress/9fc96daa0053808e9ac21bd9462d99f8':
#  - Group: compress(24cd24d8903b718fb75b05c460a01fcb)
# Submitting cluster job 'Densest/537c8e665b2104db4840de894fc79f70/compress/5dfc012334a847cbff001a3ba1455d8a':
#  - Group: compress(537c8e665b2104db4840de894fc79f70)
# Submitting cluster job 'Densest/7a3f81fcf1ab99745f585ec093ede7dc/compress/8704f3b6667f02383a71025583f23bb6':
#  - Group: compress(7a3f81fcf1ab99745f585ec093ede7dc)
# Submitting cluster job 'Densest/e20cb145126b13b2482e988a20c1f77e/compress/6f2d4f8f97e4bd6d646dba471a8a8e71':
#  - Group: compress(e20cb145126b13b2482e988a20c1f77e)
# Submitting cluster job 'Densest/bdd29dace77bd49ecc0024c2e3944986/compress/a45c9b9418983c5c942a5317a738aa11':
#  - Group: compress(bdd29dace77bd49ecc0024c2e3944986)
# Submitting cluster job 'Densest/863b56eed90961ce61e4cbcf8009a882/compress/53c6d48962b96f3e83f8b1d3aa6c75b0':
#  - Group: compress(863b56eed90961ce61e4cbcf8009a882)
# Submitting cluster job 'Densest/2da56c637d055441040a5627c10a21f3/compress/2a8f89c828e87fbf6a28e11e9fd9e121':
#  - Group: compress(2da56c637d055441040a5627c10a21f3)
# Submitting cluster job 'Densest/8787c07f9f06dd47a7f159c60db3dff0/compress/fe428459639f66c58f4fd02dbba462c1':
#  - Group: compress(8787c07f9f06dd47a7f159c60db3dff0)
# Submitting cluster job 'Densest/dd1b6e62b3391164f742a33551f3f276/compress/8ce5964df0284f8c7f1759c2283f7772':
#  - Group: compress(dd1b6e62b3391164f742a33551f3f276)
# Submitting cluster job 'Densest/757760674ab11b54ca4f3c9557abedb3/compress/2b5bdbb518fb5f62a2c6f77f6640ec38':
#  - Group: compress(757760674ab11b54ca4f3c9557abedb3)
# Submitting cluster job 'Densest/b4131121e79f48a1f39c74da124676ff/compress/fcaea2377add957b5e3646e3d5171946':
#  - Group: compress(b4131121e79f48a1f39c74da124676ff)
# Submitting cluster job 'Densest/2add11df0fd595d3de302a285039e11c/compress/b0dc7fcbe6903d69c21ae3c3be7e26d8':
#  - Group: compress(2add11df0fd595d3de302a285039e11c)
# Submitting cluster job 'Densest/41aeec925bfa146462c05ffc11a1f813/compress/201a591f1a6ecc38373269d8650e0568':
#  - Group: compress(41aeec925bfa146462c05ffc11a1f813)
# Submitting cluster job 'Densest/782d771ff1657f5444b1d09f1e8b5ef2/compress/063c7981fab6d2f9523937c91108be17':
#  - Group: compress(782d771ff1657f5444b1d09f1e8b5ef2)
# Submitting cluster job 'Densest/522a257c6a313b61facaeb731c481790/compress/1be3a7bd847aea5bc1ad25dfa6635f72':
#  - Group: compress(522a257c6a313b61facaeb731c481790)
# Submitting cluster job 'Densest/e6cbbb3c6d55f479d484c2cf3bdc531f/compress/b76e62355c4a2aa68f91a1048b20d7e5':
#  - Group: compress(e6cbbb3c6d55f479d484c2cf3bdc531f)
# Submitting cluster job 'Densest/27b58694dc4ec3251c478ad717449550/compress/18c42fdd47198ad438af73550f95a162':
#  - Group: compress(27b58694dc4ec3251c478ad717449550)
# Submitting cluster job 'Densest/2ad0ea2a4042a5af6dbe74471e8f9625/compress/fbe6eab8f71f8ccd9941c1ee8d3db3d7':
#  - Group: compress(2ad0ea2a4042a5af6dbe74471e8f9625)
# Submitting cluster job 'Densest/2910f581ee0c8c38e4ba5bc433b55bb7/compress/e044476e99e023d4a5f7d78a12c2001f':
#  - Group: compress(2910f581ee0c8c38e4ba5bc433b55bb7)
# Submitting cluster job 'Densest/fab0d86b65be1b68df33bd7b4ef9d206/compress/99caea3d0bc12f63bc5a1bb42da3cf43':
#  - Group: compress(fab0d86b65be1b68df33bd7b4ef9d206)
# Submitting cluster job 'Densest/0335cacd54e77f3a6214ce0c81e54206/compress/5fbc81d55afb83b53eeb39c0f3b8cb0b':
#  - Group: compress(0335cacd54e77f3a6214ce0c81e54206)
# Submitting cluster job 'Densest/ae97c3176fd8be80b55b11a173f620dc/compress/00dde0cd3bf4ae52bf5a7c51f94d61c4':
#  - Group: compress(ae97c3176fd8be80b55b11a173f620dc)
# Submitting cluster job 'Densest/a142facd22c217b9d3ba0d94bbd51d61/compress/877efcc3379d0c05f5545becc769cd2c':
#  - Group: compress(a142facd22c217b9d3ba0d94bbd51d61)
# Submitting cluster job 'Densest/2ccb0ae98f3b1ee5b8ce0879cee85024/compress/a09b170c4662153c78b98c37529214e2':
#  - Group: compress(2ccb0ae98f3b1ee5b8ce0879cee85024)
# Submitting cluster job 'Densest/5ddf099dd5bc98661df0e1b1a1159a21/compress/242c84cd69b401abd384274f6bf6c6bd':
#  - Group: compress(5ddf099dd5bc98661df0e1b1a1159a21)
# Submitting cluster job 'Densest/bb069eb37b5acb5201cf2bf924ffa40d/compress/cefbcbfc0064f7b830f45e9fea0a48b3':
#  - Group: compress(bb069eb37b5acb5201cf2bf924ffa40d)
# Submitting cluster job 'Densest/2a28ebe247b0b0c674efda1b1c010901/compress/9ccc91b7f41f4bf8800532817c47381d':
#  - Group: compress(2a28ebe247b0b0c674efda1b1c010901)
# Submitting cluster job 'Densest/61b20db2e46934a357998d2d522f0c5d/compress/3dbf3753134702c8e91dbf1e0bf480fa':
#  - Group: compress(61b20db2e46934a357998d2d522f0c5d)
# Submitting cluster job 'Densest/3e84e4266c9a945bf9afb71bc80a13ae/compress/bdd80a03c7efbb18edee7fecaedecd01':
#  - Group: compress(3e84e4266c9a945bf9afb71bc80a13ae)
# Submitting cluster job 'Densest/0fd0430163a14d872096d8d62f814186/compress/55cbe6d4695c63cea7b0f417dbc2abfb':
#  - Group: compress(0fd0430163a14d872096d8d62f814186)
# Submitting cluster job 'Densest/0a43c7536d962e33434f8a20603454a6/compress/eef33fc18640fd5edebed015a2a3dced':
#  - Group: compress(0a43c7536d962e33434f8a20603454a6)
# Submitting cluster job 'Densest/fd64882f81ddef149ee7e5fdc2ac662b/compress/d11b45cf20b021e8ff2d36ba988505c9':
#  - Group: compress(fd64882f81ddef149ee7e5fdc2ac662b)
# Submitting cluster job 'Densest/66841330f2f3672c0463f6d908f68b5b/compress/7f5ec359783ba601c89f71133102edfe':
#  - Group: compress(66841330f2f3672c0463f6d908f68b5b)
# Submitting cluster job 'Densest/8454c3c342ddb9bf775507dbee5dcc1d/compress/36219ca6ce0a743f52956aa2c28750e3':
#  - Group: compress(8454c3c342ddb9bf775507dbee5dcc1d)
# Submitting cluster job 'Densest/c2229a06951af831ee8fa37b11bdb77f/compress/b2ede802d387ace9f10c5bd77a64af16':
#  - Group: compress(c2229a06951af831ee8fa37b11bdb77f)
# Submitting cluster job 'Densest/515e093017e0e64e55ce1dd787d21da3/compress/2d83165474cefbb00929c35bedb83f61':
#  - Group: compress(515e093017e0e64e55ce1dd787d21da3)
# Submitting cluster job 'Densest/79603e73ac691834f40c05c6fb01060c/compress/3ab8e6d79246ecd7387a1c62c7fc425f':
#  - Group: compress(79603e73ac691834f40c05c6fb01060c)
# Submitting cluster job 'Densest/89811c86a9e18eb91bc2154b7c7edcac/compress/4449a1c5ef094a99f4933b0d4c4eb729':
#  - Group: compress(89811c86a9e18eb91bc2154b7c7edcac)
# Submitting cluster job 'Densest/ace574fa1cfcffb055519a6c07c96963/compress/1ef448bf6f82793431f8d5ece1e67277':
#  - Group: compress(ace574fa1cfcffb055519a6c07c96963)
# Submitting cluster job 'Densest/1e8ea1e99169d4cb1466b7606e176bae/compress/6d3b34aef33d462a89d9318274b211ed':
#  - Group: compress(1e8ea1e99169d4cb1466b7606e176bae)
# Submitting cluster job 'Densest/fa4e15275a491d2cbec1c38728b83e26/compress/ac7dcbf524e99c8515abad514567dc7c':
#  - Group: compress(fa4e15275a491d2cbec1c38728b83e26)
# Submitting cluster job 'Densest/0d2c7dba9a87b4b098ea74a2d4b3c6ac/compress/28b8f09cc69216802144360fcbaf748b':
#  - Group: compress(0d2c7dba9a87b4b098ea74a2d4b3c6ac)
# Submitting cluster job 'Densest/5512bda19ad1f5381099190b0fcbce3a/compress/c1e6d047dbcb78dede4b95a09f64729b':
#  - Group: compress(5512bda19ad1f5381099190b0fcbce3a)
# Submitting cluster job 'Densest/8ca76014146a3e768618b3edf7b11f4f/compress/afdb5fcccc86588b902897de3d4b16ed':
#  - Group: compress(8ca76014146a3e768618b3edf7b11f4f)
# Submitting cluster job 'Densest/5de73f24c171a85e988fda9512c94eee/compress/2cdce5baa6bcf543b6edf5f5057fdb9d':
#  - Group: compress(5de73f24c171a85e988fda9512c94eee)
# Submitting cluster job 'Densest/12a864a06377169e6136c4b1354c4968/compress/37224f6e31a68ac5c8b2e3ca1f59fc66':
#  - Group: compress(12a864a06377169e6136c4b1354c4968)
# Submitting cluster job 'Densest/fcde28e222fbb37ae32bc430d3522d3b/compress/bd2bc3cace5a37e67a49fed48ef7fa41':
#  - Group: compress(fcde28e222fbb37ae32bc430d3522d3b)
# Submitting cluster job 'Densest/d2d1f0baee0f593df7231aa76f2c0244/compress/9c82d50ee501207528acfb1fa9f2b89c':
#  - Group: compress(d2d1f0baee0f593df7231aa76f2c0244)
# Submitting cluster job 'Densest/ac2cf3d541fc3a787ce19c09e14c7ef0/compress/4a6ac381105482503609c9d7ef95a9f6':
#  - Group: compress(ac2cf3d541fc3a787ce19c09e14c7ef0)
# Submitting cluster job 'Densest/0f5a6b2c5a1bd74138b58a473676c778/compress/ade6bd9ed1fcb30493fbe7c719214a03':
#  - Group: compress(0f5a6b2c5a1bd74138b58a473676c778)
# Submitting cluster job 'Densest/ee4407fc49eed4941d4f4ad71e765859/compress/b458000f6012bc1719935c7f4253d578':
#  - Group: compress(ee4407fc49eed4941d4f4ad71e765859)
# Submitting cluster job 'Densest/4b0c660671e62443f9389bc4a4b343ff/compress/e0c5e52572f389c38e7cd8227c7de8a7':
#  - Group: compress(4b0c660671e62443f9389bc4a4b343ff)
# Submitting cluster job 'Densest/7a76b78793b8dcea3c079eb7da192572/compress/5b5af3d9ac0f4299ac7ae2013d5cf743':
#  - Group: compress(7a76b78793b8dcea3c079eb7da192572)
# Submitting cluster job 'Densest/fca4ca73623d725281801bf6adda306b/compress/27005ad910c57456b48551f0f8d2729f':
#  - Group: compress(fca4ca73623d725281801bf6adda306b)
# Submitting cluster job 'Densest/8b906fcf0a1daf8ae8e74e41440ec3ec/compress/2d1fc83865b9ca205b321b935ba11b3b':
#  - Group: compress(8b906fcf0a1daf8ae8e74e41440ec3ec)
# Submitting cluster job 'Densest/af11f43939df60d576eb511f22977e77/compress/4f3a36043fcf32c2efa2d64178ac08f1':
#  - Group: compress(af11f43939df60d576eb511f22977e77)
# Submitting cluster job 'Densest/855dd40c9685143a6a8e3a18765ef2f4/compress/d8a90e7d39bc9b064cfa203878046e15':
#  - Group: compress(855dd40c9685143a6a8e3a18765ef2f4)
# Submitting cluster job 'Densest/fe189a16768812c94299cd8ab140d633/compress/4cb0221e0d271b28c28da725863d4c5e':
#  - Group: compress(fe189a16768812c94299cd8ab140d633)
# Submitting cluster job 'Densest/8fea93892617a765f2a6008e5d457de6/compress/408a7bbc0941fd372b61ba5eea53a546':
#  - Group: compress(8fea93892617a765f2a6008e5d457de6)
# Submitting cluster job 'Densest/64a1c0bae773095030bfbbfea4323413/compress/d4f7ee09436d19ce995aa6421e4d700b':
#  - Group: compress(64a1c0bae773095030bfbbfea4323413)
# Submitting cluster job 'Densest/406d9fc78bdf9fb971da0981c3f6ad3c/compress/ee4b18681a8b79552aeed4a8afb43160':
#  - Group: compress(406d9fc78bdf9fb971da0981c3f6ad3c)
# Submitting cluster job 'Densest/8d68ff0407eca549b11e092bc8ae7bdc/compress/80bfee58403385c9e7fdf5235811bc33':
#  - Group: compress(8d68ff0407eca549b11e092bc8ae7bdc)
# Submitting cluster job 'Densest/80ebd1e0949723aa65bb1d5eb3c66731/compress/46d06d82455d6c69dd5075947846186f':
#  - Group: compress(80ebd1e0949723aa65bb1d5eb3c66731)
# Submitting cluster job 'Densest/69e323e805f7f4b27b6db6f7f7f797f8/compress/a250cc015a58a6f1b7b43512327a6cd4':
#  - Group: compress(69e323e805f7f4b27b6db6f7f7f797f8)
# Submitting cluster job 'Densest/c1c49eb4bcdc1625b18f75ccd594aca7/compress/be52c040f5409d78d4fdc80cf0e1c8a5':
#  - Group: compress(c1c49eb4bcdc1625b18f75ccd594aca7)
# Submitting cluster job 'Densest/ce5d46d1a321be524523e33a1e0b7bc2/compress/898eb10e7cb044922979e4fbd1220e56':
#  - Group: compress(ce5d46d1a321be524523e33a1e0b7bc2)
# Submitting cluster job 'Densest/eb9fbd84e778dc7d22f21248a879716e/compress/4ef02a75cbcbb3a6492ab00de003919c':
#  - Group: compress(eb9fbd84e778dc7d22f21248a879716e)
# Submitting cluster job 'Densest/7094e0a2fc6041844f4718a3ddf12c6c/compress/80cb81d61bd1c0e85cbc2f43bd4504f5':
#  - Group: compress(7094e0a2fc6041844f4718a3ddf12c6c)
# Submitting cluster job 'Densest/759dfae84c9c8566bb76b667128529b3/compress/643a94a61ee05619ca1ba0df584bd0d7':
#  - Group: compress(759dfae84c9c8566bb76b667128529b3)
# Submitting cluster job 'Densest/9f07f56eeb1f654ee7774939261411fe/compress/09262f693e9667f2d2c82abc48760192':
#  - Group: compress(9f07f56eeb1f654ee7774939261411fe)
#
# Exit Code: 0
# Check Status Command:
# cd  /home/jwang/HOOMD_HPMC/test11_2d/DensestProject
# watch -n 1 python3 project.py status

# %% [markdown]
# ##### 步骤3：等待全部进程运行结束，运行下面的代码找到最密晶格。

# %%
# NO NEED TO CHANGE THIS
init.analysis()
init.create_sample0()
# Out:
# get successfully. packing fraction : 0.999989856407606
# 'sample0.gsd'

# %% [markdown]
# # 二、制作不同密度的样品，同时计算压强值

# %% [markdown]
# #### 生成project和job。对于流体和固体生成不同project。

# %% [markdown]
# ### Fluid Pipeline

# %% [markdown]
# 对于流体计算，工作流如下：设定一组目标压强。首先，将原初样品的密度设为 $0.001$（逼近理想气体），令体系随机化。其次，对每个样品进行常规的 $NPT$ 模拟一定步数，以压缩至设定的压强（密度）。最后，在 $NVT$ 系综里，采样压强值。
#
# 流体样品的密度需要从平衡态读取，而非初始指定。
#
# 工作流同时支持 $Widom$ 插入粒子法计算化学势。

# %%
# !rm -r Fluid

# %%
# 结束本次任务
# %cd Fluid
import os
open('cancel.sh', 'w')
for filename in os.listdir(os.getcwd()):
    if filename.startswith("slurm"):
        with open('cancel.sh', "a+") as f:
            f.write(f'scancel {filename[6:-4]}\n' )
# !bash cancel.sh
os.remove('cancel.sh')
# !rm slurm*
# %cd ..
# Out:
# /home/jwang/HOOMD_HPMC/amazing_v2_test/Fluid
# /home/jwang/HOOMD_HPMC/amazing_v2_test

# %%
# Fluid Project
from flow import FlowProject
import os
import numpy as np
betaPs = np.arange(0.01, 8, 0.5)
replication = [8, 8, 8]
fluidsample0 = "/sample0.gsd"
samplename = "/sample.gsd"
seeds = [12345]
equilibrum_steps = 1e6
sampling_steps = 1e6

class Fluid(FlowProject):
    pass

project = Fluid.init_project("Fluid")

for betaP in betaPs:
    for seed in seeds:
        job = project.open_job({'betaP': betaP,'seed':seed}).init()
        with job:
            init.create_sample(0.001, replication, job.path + fluidsample0)
path = os.getcwd()  # get the absolute path of the current working directory
f = open(path + "/Fluid/project.py", "w")  # open 'project.py' file
# Out:
# /home/jwang/miniforge3/envs/hd5/lib/python3.13/site-packages/synced_collections/numpy_utils.py:46: NumpyConversionWarning: Any numpy types provided will be transparently converted to the closest base Python equivalents.
#   warnings.warn(NUMPY_CONVERSION_WARNING, NumpyConversionWarning)

# %%
lines = [
    "from flow import FlowProject\n",
    "import os\n",
    "import sys\n",
    "sys.path.append(os.getcwd() + \"/..\")\n",
    "import hcpmc\n",
    f"sample0name = \"{fluidsample0}\"\n"
    f"samplename = \"{samplename}\"\n",
    f"factory = {factorystr}\n"
    f"equilibrum_steps = int({equilibrum_steps})\n",
    f"sampling_steps = int({sampling_steps})\n",
    "class Fluid(FlowProject):\n",
    "    pass\n",
    "@Fluid.label\n",
    "def betaP_ed(job):\n",
    "    return \"Pressure\" in job.document\n",
    "@Fluid.post(betaP_ed)\n",
    "@Fluid.operation(directives={'memory': '1g', 'walltime': 24})\n",
    "def compute_betaP(job):\n",
    "    with job:\n",
    "        P = hcpmc.equilibrium.fluid.Pressure(job.path + samplename, job.path + sample0name, factory)\n",
    "        P.calculate(job.sp.betaP, equilibrum_steps, sampling_steps, job.sp.seed)\n",
    "        job.doc[\"Pressure\"] = P.get_pressure()\n",
    "        job.doc[\"packing_fraction\"] = P.packingfraction\n",
    "        os.remove(job.path + sample0name)\n",
    
    "@Fluid.label\n",
    "def mu_ed(job):\n",
    "    return \"mu\" in job.document\n",
    "@Fluid.post(mu_ed)\n",
    "@Fluid.operation(directives={'memory': '1g', 'walltime': 24})\n",
    "def compute_mu(job):\n",
    "    with job:\n",
    "        mu = hcpmc.equilibrium.fluid.ChemicalPotential(job.path + samplename, factory)\n",
    "        mu.calculate(equilibrum_steps, sampling_steps, job.sp.seed)\n",
    "        job.doc[\"mu\"] = mu.get_chemical_potential()\n",
    
    "if __name__ == \"__main__\":\n",
    "    Fluid().main()\n",
    ]

f.writelines(lines)
f.flush()

# %%
# NO NEED TO CHANGE THIS
# %cd Fluid
# !python3 project.py submit -o compute_betaP
# %cd ..
path = os.getcwd() + '/Fluid'
print('cd '+path)
print('watch -n 1 python3 project.py status')
# Out:
# /home/jwang/HOOMD_HPMC/amazing_v2_test/Fluid
# Querying scheduler...
# /home/jwang/HOOMD_HPMC/amazing_v2_test
# cd /home/jwang/HOOMD_HPMC/amazing_v2_test/Fluid
# watch -n 1 python project.py status

# %% [markdown]
# ### Solid Pipeline

# %% [markdown]
# 对于固体计算，工作流如下：设定一组样品密度。首先，对每个密度，通过原初样品的按比例扩张成为可用样品。然后，对每个样品在$Isothermal-Isobaric$ 系综内平衡一定步数后采样。

# %%
# Solid Project
from flow import FlowProject
import os
import numpy as np
packing_fractions = np.arange(0.7, 0.9, 0.01)
replication = [10,10]
samplename = "/sample.gsd"
seeds = [12345]
equilibrum_steps = 1e5
sampling_steps = 1e5

class Solid(FlowProject):
    pass


project = Solid.init_project("Solid")

for pf in packing_fractions:
    for seed in seeds:
        job = project.open_job({'pf': pf,'seed':seed}).init()
        with job:
            init.create_sample(pf, replication, job.path + samplename)
path = os.getcwd()  # get the absolute path of the current working directory
f = open(path + "/Solid/project.py", "w")  # open 'project.py' file
# Out:
# /home/jwang/miniforge3/envs/hd5/lib/python3.13/site-packages/synced_collections/numpy_utils.py:46: NumpyConversionWarning: Any numpy types provided will be transparently converted to the closest base Python equivalents.
#   warnings.warn(NUMPY_CONVERSION_WARNING, NumpyConversionWarning)

# %%
lines = [
    "from flow import FlowProject\n",
    "import numpy as np\n",
    "import os\n",
    "import sys\n",
    "sys.path.append(os.getcwd() + \"/..\")\n",
    "import hcpmc\n",
    f"samplename = \"{samplename}\"\n",
    f"factory = {factorystr}\n"
    f"equilibrum_steps = int({equilibrum_steps})\n",
    f"sampling_steps = int({sampling_steps})\n",
    "class Solid(FlowProject):\n",
    "    pass\n",
    "@Solid.label\n",
    "def betaP_ed(job):\n",
    "    return \"Pressure\" in job.document\n",
    "@Solid.post(betaP_ed)\n",
    "@Solid.operation(directives={'memory': '1g', 'walltime': 48})\n",
    "def compute_betaP(job):\n",
    "    with job:\n",
    "        P = hcpmc.equilibrium.solid.Pressure(job.path + samplename, factory)\n",
    "        P.calculate(equilibrum_steps, sampling_steps, job.sp.seed)\n",
    "        job.doc[\"Pressure\"] = P.get_pressure()\n",
    "        job.doc[\"packing_fraction\"] = P.packingfraction\n",
    

    "if __name__ == \"__main__\":\n",
    "    Solid().main()\n",
    ]

f.writelines(lines)
f.flush()

# %%
# NO NEED TO CHANGE THIS
# %cd Solid
# !python3 project.py submit -o compute_betaP
# %cd ..
path = os.getcwd() + '/Solid'
print('cd '+path)
print('watch -n 1 python3 project.py status')
# Out:
# /home/jwang/HOOMD_HPMC/test11_2d/Solid
# Querying scheduler...
# Submitting cluster job 'Solid/d91caec83b6771a3cf5e2d28e320fcb9/compute_beta/ab844da2130722559dd5f51cf400d533':
#  - Group: compute_betaP(d91caec83b6771a3cf5e2d28e320fcb9)
# Submitting cluster job 'Solid/0f91ab0b788af858b465d2bf643fc61e/compute_beta/57391bd555b0479ddf429254fad57867':
#  - Group: compute_betaP(0f91ab0b788af858b465d2bf643fc61e)
# Submitting cluster job 'Solid/749619d116be15471da23375b19df462/compute_beta/6d1c46f86e5904ac96c046616b94795c':
#  - Group: compute_betaP(749619d116be15471da23375b19df462)
# Submitting cluster job 'Solid/35e8a50c4333d9f939a9653511703695/compute_beta/6f1be6d6c5a76b770494e8e671b1aa6a':
#  - Group: compute_betaP(35e8a50c4333d9f939a9653511703695)
# Submitting cluster job 'Solid/ecc799bae9df3905857da2831705fd83/compute_beta/2a7e083fabb3a831ba3e16aeefba047c':
#  - Group: compute_betaP(ecc799bae9df3905857da2831705fd83)
# Submitting cluster job 'Solid/b9a60a62c7eb31f762b719c7f03406d5/compute_beta/25b735b7a0ac4815ca3fa56f4a2a1a46':
#  - Group: compute_betaP(b9a60a62c7eb31f762b719c7f03406d5)
# Submitting cluster job 'Solid/a73b1ed34c959dbc736af0e6b0ede6fc/compute_beta/4d177d4e7547f818a151d8a8d031e1ac':
#  - Group: compute_betaP(a73b1ed34c959dbc736af0e6b0ede6fc)
# Submitting cluster job 'Solid/e377fd51a6c1eb137e8bd1380612bc1f/compute_beta/30f1289e7d10586674bb652636742c25':
#  - Group: compute_betaP(e377fd51a6c1eb137e8bd1380612bc1f)
# Submitting cluster job 'Solid/436174bec6e16a73ac5c0f7392d939e8/compute_beta/f13f262221dec7d43aba7414ad083859':
#  - Group: compute_betaP(436174bec6e16a73ac5c0f7392d939e8)
# Submitting cluster job 'Solid/b9f772db2e5fa950f4468f71afef75f9/compute_beta/7d6855d4011779e4a456276339ed37a5':
#  - Group: compute_betaP(b9f772db2e5fa950f4468f71afef75f9)
# Submitting cluster job 'Solid/0d96fbf2590aff5183767929aa11e221/compute_beta/559f43e5c4fb53f1b4977051f8c36557':
#  - Group: compute_betaP(0d96fbf2590aff5183767929aa11e221)
# Submitting cluster job 'Solid/0a4497a6f8633ae39c9b695cae928a71/compute_beta/ea7e271a280abf689c4daa4fef57d6c4':
#  - Group: compute_betaP(0a4497a6f8633ae39c9b695cae928a71)
# Submitting cluster job 'Solid/e16900fbc396043391c37f0cb7b9487f/compute_beta/668edecdb33ad862b0f95a24478f4559':
#  - Group: compute_betaP(e16900fbc396043391c37f0cb7b9487f)
# Submitting cluster job 'Solid/2e94bee4bfe687f8b3e05f0fc159a0b6/compute_beta/c65f652e64fc2a3814127cef76075295':
#  - Group: compute_betaP(2e94bee4bfe687f8b3e05f0fc159a0b6)
# Submitting cluster job 'Solid/5aca0bb0ac462d75a7353250ecdb85bc/compute_beta/dd4d3d8867954633bc0e0172eaef056e':
#  - Group: compute_betaP(5aca0bb0ac462d75a7353250ecdb85bc)
# Submitting cluster job 'Solid/ad18c17ddb1f95023a68df074c5a20af/compute_beta/1b606c5d201b9994a7106f61cbd0459d':
#  - Group: compute_betaP(ad18c17ddb1f95023a68df074c5a20af)
# Submitting cluster job 'Solid/bb1063f6a4e4ea7d2f895ace17d672fd/compute_beta/698d27c4d2cc1a0e73e3fc93ea69140a':
#  - Group: compute_betaP(bb1063f6a4e4ea7d2f895ace17d672fd)
# Submitting cluster job 'Solid/953acaa30c5c61f3bafcc4c3c660d744/compute_beta/d625a7580ef8243c002604e8573dbf8d':
#  - Group: compute_betaP(953acaa30c5c61f3bafcc4c3c660d744)
# Submitting cluster job 'Solid/1d1082415698272bb48b4cd93e1aa451/compute_beta/27ff50f4e8cf8119cd3d9cf465ff7d97':
#  - Group: compute_betaP(1d1082415698272bb48b4cd93e1aa451)
# Submitting cluster job 'Solid/bcf147aa3092475c7fe93a52d1707ca5/compute_beta/81261784ab983210773de3cc52f198f2':
#  - Group: compute_betaP(bcf147aa3092475c7fe93a52d1707ca5)
# Submitting cluster job 'Solid/d81e86836e1f3aba126e2ea774b2c93c/compute_beta/8e3b3d0a2c71becb2719426588030e6a':
#  - Group: compute_betaP(d81e86836e1f3aba126e2ea774b2c93c)
# /home/jwang/HOOMD_HPMC/test11_2d
# cd /home/jwang/HOOMD_HPMC/test11_2d/Solid
# watch -n 1 python3 project.py status

# %% [markdown]
# # 三、固体样品的自由能计算

# %% [markdown]
# ### Frenkel-Ladd Pipeline

# %% [markdown]
#  $Frenkel-Ladd$ 方法是计算样品绝对自由能的一种方式。工作流如下：前提，由二完成样品的制作。首先，给定要计算的样品的密度区间，选出可用的样品。然后，对每个 job 样品又创建了自己的 FreeEnergy Project，并提交到计算集群。接着，等待所有 job 完成，最后汇总结果，得到样品的绝对自由能。
#
#  这里实际上在 Solid Project 的特定 job 中，又创建了新的 FreeEnergy Project 。

# %%
import signac
from flow import FlowProject
import numpy as np
import subprocess
import sys
import shutil

compute_pf_mn = 0.7
compute_pf_mx = 0.9
samplename = '/sample.gsd'
FL_equilibrum_steps = 2e4
FL_sampling_steps = 3e4
seeds = [12345]

class FreeEnergy(FlowProject):
    pass


project = signac.get_project("Solid")
for job in project:
    if 'pf' not in job.sp:
        shutil.rmtree(job.path)

# %%
import signac
from flow import FlowProject
import numpy as np

path = os.getcwd()
compute_pf_mn = 0.7
compute_pf_mx = 0.9
samplename = '/sample.gsd'
FL_equilibrum_steps = 2e4
FL_sampling_steps = 3e4
seeds = [12345]

class FreeEnergy(FlowProject):
    pass


project = signac.get_project("Solid")
for job in project:
    if job.sp.pf > compute_pf_mn - 1e-3 and job.sp.pf < compute_pf_mx + 1e-3:
        proj = FreeEnergy.init_project(job.path +"/FreeEnergy")
        ks = 10 ** (np.linspace(5 * (job.sp.pf + 0.2) - 7, 5 * (job.sp.pf + 0.2), 30))
        for k in ks:
            for seed in seeds:
                sp = dict(k=k, seed=seed)
                proj.open_job(sp).init()
        f = open(job.path + "/FreeEnergy/project.py", "w")
        code_lines = [
            "from flow import FlowProject\n",
            "import sys\n",
            "import os\n",
            f'sys.path.append("{path}")\n',
            "import hcpmc\n",
            f'samplename = os.getcwd() + "/..{samplename}"\n',
            f"factory = {factorystr}\n",
            f"equilibrium_steps = int({FL_equilibrum_steps})\n",
            f"sampling_steps = int({FL_sampling_steps})\n",
            "class FreeEnergy(FlowProject):\n",
            "    pass\n",
            "@FreeEnergy.label\n",
            "def finish(job):\n",
            '    return "dF" in job.document\n',
            "@FreeEnergy.post(finish)\n",
            "@FreeEnergy.operation(directives={'memory': '1g', 'walltime': 24})\n",
            "def sample(job):\n",
            "    with job:\n",
            "        H = hcpmc.equilibrium.solid.Harmonic(samplename, factory, job.sp.k)\n",
            "        H.calculate(equilibrium_steps, sampling_steps, job.sp.seed)\n",
            '        job.doc["dF"] = H.dF\n',
            'if __name__ == "__main__":\n',
            "    FreeEnergy().main()\n",
        ]
        f.writelines(code_lines)
        f.flush()
# Out:
# /home/jwang/miniforge3/envs/hd5/lib/python3.13/site-packages/synced_collections/numpy_utils.py:46: NumpyConversionWarning: Any numpy types provided will be transparently converted to the closest base Python equivalents.
#   warnings.warn(NUMPY_CONVERSION_WARNING, NumpyConversionWarning)
# /home/jwang/miniforge3/envs/hd5/lib/python3.13/site-packages/synced_collections/numpy_utils.py:46: NumpyConversionWarning: Any numpy types provided will be transparently converted to the closest base Python equivalents.
#   warnings.warn(NUMPY_CONVERSION_WARNING, NumpyConversionWarning)
# /home/jwang/miniforge3/envs/hd5/lib/python3.13/site-packages/synced_collections/numpy_utils.py:46: NumpyConversionWarning: Any numpy types provided will be transparently converted to the closest base Python equivalents.
#   warnings.warn(NUMPY_CONVERSION_WARNING, NumpyConversionWarning)
# /home/jwang/miniforge3/envs/hd5/lib/python3.13/site-packages/synced_collections/numpy_utils.py:46: NumpyConversionWarning: Any numpy types provided will be transparently converted to the closest base Python equivalents.
#   warnings.warn(NUMPY_CONVERSION_WARNING, NumpyConversionWarning)
# /home/jwang/miniforge3/envs/hd5/lib/python3.13/site-packages/synced_collections/numpy_utils.py:46: NumpyConversionWarning: Any numpy types provided will be transparently converted to the closest base Python equivalents.
#   warnings.warn(NUMPY_CONVERSION_WARNING, NumpyConversionWarning)
# /home/jwang/miniforge3/envs/hd5/lib/python3.13/site-packages/synced_collections/numpy_utils.py:46: NumpyConversionWarning: Any numpy types provided will be transparently converted to the closest base Python equivalents.
#   warnings.warn(NUMPY_CONVERSION_WARNING, NumpyConversionWarning)
# /home/jwang/miniforge3/envs/hd5/lib/python3.13/site-packages/synced_collections/numpy_utils.py:46: NumpyConversionWarning: Any numpy types provided will be transparently converted to the closest base Python equivalents.
#   warnings.warn(NUMPY_CONVERSION_WARNING, NumpyConversionWarning)
# /home/jwang/miniforge3/envs/hd5/lib/python3.13/site-packages/synced_collections/numpy_utils.py:46: NumpyConversionWarning: Any numpy types provided will be transparently converted to the closest base Python equivalents.
#   warnings.warn(NUMPY_CONVERSION_WARNING, NumpyConversionWarning)
# /home/jwang/miniforge3/envs/hd5/lib/python3.13/site-packages/synced_collections/numpy_utils.py:46: NumpyConversionWarning: Any numpy types provided will be transparently converted to the closest base Python equivalents.
#   warnings.warn(NUMPY_CONVERSION_WARNING, NumpyConversionWarning)
# /home/jwang/miniforge3/envs/hd5/lib/python3.13/site-packages/synced_collections/numpy_utils.py:46: NumpyConversionWarning: Any numpy types provided will be transparently converted to the closest base Python equivalents.
#   warnings.warn(NUMPY_CONVERSION_WARNING, NumpyConversionWarning)
# /home/jwang/miniforge3/envs/hd5/lib/python3.13/site-packages/synced_collections/numpy_utils.py:46: NumpyConversionWarning: Any numpy types provided will be transparently converted to the closest base Python equivalents.
#   warnings.warn(NUMPY_CONVERSION_WARNING, NumpyConversionWarning)
# /home/jwang/miniforge3/envs/hd5/lib/python3.13/site-packages/synced_collections/numpy_utils.py:46: NumpyConversionWarning: Any numpy types provided will be transparently converted to the closest base Python equivalents.
#   warnings.warn(NUMPY_CONVERSION_WARNING, NumpyConversionWarning)
# /home/jwang/miniforge3/envs/hd5/lib/python3.13/site-packages/synced_collections/numpy_utils.py:46: NumpyConversionWarning: Any numpy types provided will be transparently converted to the closest base Python equivalents.
#   warnings.warn(NUMPY_CONVERSION_WARNING, NumpyConversionWarning)
# /home/jwang/miniforge3/envs/hd5/lib/python3.13/site-packages/synced_collections/numpy_utils.py:46: NumpyConversionWarning: Any numpy types provided will be transparently converted to the closest base Python equivalents.
#   warnings.warn(NUMPY_CONVERSION_WARNING, NumpyConversionWarning)
# /home/jwang/miniforge3/envs/hd5/lib/python3.13/site-packages/synced_collections/numpy_utils.py:46: NumpyConversionWarning: Any numpy types provided will be transparently converted to the closest base Python equivalents.
#   warnings.warn(NUMPY_CONVERSION_WARNING, NumpyConversionWarning)
# /home/jwang/miniforge3/envs/hd5/lib/python3.13/site-packages/synced_collections/numpy_utils.py:46: NumpyConversionWarning: Any numpy types provided will be transparently converted to the closest base Python equivalents.
#   warnings.warn(NUMPY_CONVERSION_WARNING, NumpyConversionWarning)
# /home/jwang/miniforge3/envs/hd5/lib/python3.13/site-packages/synced_collections/numpy_utils.py:46: NumpyConversionWarning: Any numpy types provided will be transparently converted to the closest base Python equivalents.
#   warnings.warn(NUMPY_CONVERSION_WARNING, NumpyConversionWarning)
# /home/jwang/miniforge3/envs/hd5/lib/python3.13/site-packages/synced_collections/numpy_utils.py:46: NumpyConversionWarning: Any numpy types provided will be transparently converted to the closest base Python equivalents.
#   warnings.warn(NUMPY_CONVERSION_WARNING, NumpyConversionWarning)
# /home/jwang/miniforge3/envs/hd5/lib/python3.13/site-packages/synced_collections/numpy_utils.py:46: NumpyConversionWarning: Any numpy types provided will be transparently converted to the closest base Python equivalents.
#   warnings.warn(NUMPY_CONVERSION_WARNING, NumpyConversionWarning)
# /home/jwang/miniforge3/envs/hd5/lib/python3.13/site-packages/synced_collections/numpy_utils.py:46: NumpyConversionWarning: Any numpy types provided will be transparently converted to the closest base Python equivalents.
#   warnings.warn(NUMPY_CONVERSION_WARNING, NumpyConversionWarning)
# /home/jwang/miniforge3/envs/hd5/lib/python3.13/site-packages/synced_collections/numpy_utils.py:46: NumpyConversionWarning: Any numpy types provided will be transparently converted to the closest base Python equivalents.
#   warnings.warn(NUMPY_CONVERSION_WARNING, NumpyConversionWarning)

# %%
import signac
from flow import FlowProject
import numpy as np
import os

project = signac.get_project("Solid")
for job in project:
    if job.sp.pf > compute_pf_mn - 1e-3 and job.sp.pf < compute_pf_mx + 1e-3:
        lines = [
            "#!/bin/bash\n",
            "cd ",
            job.path,
            "/FreeEnergy\n",
            "python3 project.py submit -o sample",
        ]
        with open("submit.sh", "w") as f:
            f.writelines(lines)
        # !bash submit.sh
os.remove("submit.sh")
# Out:
# Querying scheduler...
# Submitting cluster job 'FreeEnergy/471763824a435d5359209c06920d13e4/sample/77b4b32a3eca93c021ce821b026f377b':
#  - Group: sample(471763824a435d5359209c06920d13e4)
# Submitting cluster job 'FreeEnergy/7f340895b00bb138164fd4c6af70d716/sample/c7177ec7cbf0decbb01c0cb2837cf21a':
#  - Group: sample(7f340895b00bb138164fd4c6af70d716)
# Submitting cluster job 'FreeEnergy/70f2d2c2221be0893ec63467c5b1bae9/sample/d96f83e09c599e2d64c4d0c377e21ad5':
#  - Group: sample(70f2d2c2221be0893ec63467c5b1bae9)
# Submitting cluster job 'FreeEnergy/1be75c42fe7d3f14e361b0adc39156a4/sample/c04d44172f1df4e084c9e5813b1cbe27':
#  - Group: sample(1be75c42fe7d3f14e361b0adc39156a4)
#  - Group: sample(bdb6ce4378f6aba81c9403735e09e0b6)
# Submitting cluster job 'FreeEnergy/15a04c5985d0c8544395d84a05716691/sample/ecef0a4450843809ffdb5d33b41227a7':
#  - Group: sample(15a04c5985d0c8544395d84a05716691)
# Submitting cluster job 'FreeEnergy/5e827219bbe44fece9f08afa40132778/sample/452889ca15c27f273bfc08b142784cd6':
#  - Group: sample(5e827219bbe44fece9f08afa40132778)
# Submitting cluster job 'FreeEnergy/d02cfb4027c7efbbd689adf915ff756d/sample/1560968791babbddf576af2086937ca2':
#  - Group: sample(d02cfb4027c7efbbd689adf915ff756d)
# Submitting cluster job 'FreeEnergy/0a4f9e6f8a1fa802ca0eec336968c86c/sample/58dfc22c9d30af6b0785c25058f0167b':
#  - Group: sample(0a4f9e6f8a1fa802ca0eec336968c86c)
# Submitting cluster job 'FreeEnergy/04b9035288994a67195f32c5a2fe9bfe/sample/0f7313184239115faecb33b4b1a5d6dc':
#  - Group: sample(04b9035288994a67195f32c5a2fe9bfe)
# Submitting cluster job 'FreeEnergy/c31413aebe88ee2627f0f8375129df70/sample/6e0d7d28fd92bff798bfa3af33230b10':
#  - Group: sample(c31413aebe88ee2627f0f8375129df70)
# Submitting cluster job 'FreeEnergy/5dacf3a2c24a814b1862604eb91ba685/sample/62a52c4fde5a7feb357511cc5f783074':
#  - Group: sample(5dacf3a2c24a814b1862604eb91ba685)
# Submitting cluster job 'FreeEnergy/1abb45d23bc4a55586f0c7cd1c3bd145/sample/09055becbe0b11cc58cad90adc3a0c56':
#  - Group: sample(1abb45d23bc4a55586f0c7cd1c3bd145)
# Submitting cluster job 'FreeEnergy/096801b22cb8cd304c256367fee0ef5a/sample/02b33f7f3f4b7c8f43ff7a657b294e97':
#  - Group: sample(096801b22cb8cd304c256367fee0ef5a)
# Submitting cluster job 'FreeEnergy/3c6539da9ea2c0718b4782aa857b5e8d/sample/b25e5f120c23616b6ef6190ec939c8f4':
#  - Group: sample(3c6539da9ea2c0718b4782aa857b5e8d)
# Submitting cluster job 'FreeEnergy/e35ff7ed0877e6da4951b92036f5e192/sample/05ecaf19dd0ddd771941f99708980b36':
#  - Group: sample(e35ff7ed0877e6da4951b92036f5e192)
# Submitting cluster job 'FreeEnergy/7fb16b594f0274c616c3efca4fb9faa1/sample/d8c057e4cffc6865bd7b98f55eb39ec4':
#  - Group: sample(7fb16b594f0274c616c3efca4fb9faa1)
# Submitting cluster job 'FreeEnergy/798d24a4d2ac6ad6db56822c4383246c/sample/b261d1110dc470c7a2eefd613b5b0fb2':
#  - Group: sample(798d24a4d2ac6ad6db56822c4383246c)
# Submitting cluster job 'FreeEnergy/bbeed7960ed6da030b0e2b6516f5e168/sample/5dcaa05f098902a947cc4d2f595560e6':
#  - Group: sample(bbeed7960ed6da030b0e2b6516f5e168)
# Submitting cluster job 'FreeEnergy/f6087c83874646fa3fdb7a23a46db59f/sample/1545dec0064137ff28bd9be4fb00fae5':
#  - Group: sample(f6087c83874646fa3fdb7a23a46db59f)
# Submitting cluster job 'FreeEnergy/84008f9a85a0edceccc38b5bf36b67e0/sample/e2dfc0248b70c58004c8f5f05ca73c6f':
#  - Group: sample(84008f9a85a0edceccc38b5bf36b67e0)
# Submitting cluster job 'FreeEnergy/765c37d4cd36ebc285bbcebf3c863e98/sample/b8c59e052619534958d94b3b96d32495':
#  - Group: sample(765c37d4cd36ebc285bbcebf3c863e98)
# Submitting cluster job 'FreeEnergy/5d0dddf4920a5875277092f6ce7d42e4/sample/2d89d4dee88ff2559de044c27537d36f':
#  - Group: sample(5d0dddf4920a5875277092f6ce7d42e4)
# Submitting cluster job 'FreeEnergy/7a8f6cc89461c33ec78bd29c5444c324/sample/da38d8d2e5b31e6c5dcae673ac2666b7':
#  - Group: sample(7a8f6cc89461c33ec78bd29c5444c324)
# Submitting cluster job 'FreeEnergy/210fbfe668e7b293177717535020d409/sample/d9c248fc878ae2de6ad25aed97707379':
#  - Group: sample(210fbfe668e7b293177717535020d409)
# Querying scheduler...
# Submitting cluster job 'FreeEnergy/3c3a4e3270c109609c3f68b05c0f24dd/sample/d75505415129ce5242b1caf12aa5230e':
#  - Group: sample(3c3a4e3270c109609c3f68b05c0f24dd)
# Submitting cluster job 'FreeEnergy/0f236737beed894f664f94d4bdfebff2/sample/bbfb74b24840d93a318e14334551be09':
#  - Group: sample(0f236737beed894f664f94d4bdfebff2)
# Submitting cluster job 'FreeEnergy/b690963c847aadc50e86c67e9d958fda/sample/5cca043fc2d327f7f104ed59e0479659':
#  - Group: sample(b690963c847aadc50e86c67e9d958fda)
# Submitting cluster job 'FreeEnergy/f08e2df6deaa0b8a98eba5ea6205d8c6/sample/6fd7d95e54bc66a0bd74ba9143862670':
#  - Group: sample(f08e2df6deaa0b8a98eba5ea6205d8c6)
# Submitting cluster job 'FreeEnergy/a5170bcc7a60ffb35120e713c3c51745/sample/2adf965d77f1732c332448521770108c':
#  - Group: sample(a5170bcc7a60ffb35120e713c3c51745)
# Submitting cluster job 'FreeEnergy/ff4324dd46180c6cab6b74f7c75eae5e/sample/c142001bb2b7de9026b1e52e6c1d7fcb':
#  - Group: sample(ff4324dd46180c6cab6b74f7c75eae5e)
# Submitting cluster job 'FreeEnergy/7d1a5493adcfe63879f2bfc3c9798817/sample/bb486418430b4f962a107c780e8c4dfb':
#  - Group: sample(7d1a5493adcfe63879f2bfc3c9798817)
# Submitting cluster job 'FreeEnergy/448bdf7fdead871070c303009a6354cb/sample/352d88780e6f623ef2be3160a55a0b64':
#  - Group: sample(448bdf7fdead871070c303009a6354cb)
# Submitting cluster job 'FreeEnergy/3836dab9f5a141798b9c29f41eb51533/sample/1d9eb68e2ebf7a36605313c7f5b71a43':
#  - Group: sample(3836dab9f5a141798b9c29f41eb51533)
# Submitting cluster job 'FreeEnergy/f92de2a97214b0ef3a2a087207db5b98/sample/94c780c7fbd62a7089725e2c0d935a6c':
#  - Group: sample(f92de2a97214b0ef3a2a087207db5b98)
# Submitting cluster job 'FreeEnergy/239858050ca7363542aa219bce6fd006/sample/24b55933beaad7901bd80b84c0d0e27d':
#  - Group: sample(239858050ca7363542aa219bce6fd006)
# Submitting cluster job 'FreeEnergy/4f8be9ab58fa27e2bf1c9329156109ed/sample/1ba77e0b5b243d2d8148627c5051afd0':
#  - Group: sample(4f8be9ab58fa27e2bf1c9329156109ed)

# %%
import signac
import gsd.hoomd
import matplotlib.pyplot as plt

project = signac.get_project("Solid")
for job in project:
    if job.sp.pf > compute_pf_mn - 1e-3 and job.sp.pf < compute_pf_mx + 1e-3:
        samplename = job.path + "/sample.gsd"
        Nsym = len(factory.get_symmetries())
        with gsd.hoomd.open(samplename, "r") as f:
            N = f[0].particles.N
            box = f[0].configuration.box
            V = box[0] * box[1]
            if box[2] != 0:
                V *= box[2]
            rho = N / V
        FE_project = signac.get_project(job.path + "/FreeEnergy")
        free_energy = []
        for seed in seeds:
            energy_temp = dict()
            for subjob in FE_project:
                if subjob.sp.seed == seed:
                    try:
                        energy_temp[subjob.sp.k] = subjob.document["dF"]
                    except:
                        print("Error in " + subjob.path)
            ks = np.array(sorted(energy_temp.keys()))
            energy_temp = np.array([energy_temp[k] for k in ks])
            plt.plot(ks, energy_temp, "o")
            plt.xscale("log")
            integral = np.trapz(energy_temp, np.log(ks))
            F_Ein = (
                -1.0 * (N - 1) / N * np.log(np.pi / (ks[-1] / 2))
                - 1 / 2 * np.log(np.pi / (ks[-1] / 2))
                + np.log(2 * np.pi)
                - np.log(Nsym)
            )
            dF_CM = (-np.log(rho) + 2 / 2 * np.log(N)) / N
            F_ig = np.log(rho) - 1
            free_energy.append(F_Ein - integral - dF_CM)
        free_energy = np.array(free_energy)
        print(free_energy.mean(), "+/-", free_energy.std() / np.sqrt(len(free_energy)))
        job.doc["free_energy"] = (
            f"{free_energy.mean()} +/- {free_energy.std() / np.sqrt(len(free_energy))}"
        )
# Out:
# /tmp/ipykernel_3571886/3155620870.py:31: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   integral = np.trapz(energy_temp, np.log(ks))
# 4.088979694094141 +/- 0.0
# 4.4315141930580735 +/- 0.0
# 5.44191951651007 +/- 0.0
# 5.901022917979248 +/- 0.0
# 3.7522572124104316 +/- 0.0
# 6.7124730961545644 +/- 0.0
# 1.5168289154232035 +/- 0.0
# 3.4424435314863784 +/- 0.0
# 5.667002958003352 +/- 0.0
# 4.2507021794786874 +/- 0.0
# 6.428668930106804 +/- 0.0
# 2.3954000694593063 +/- 0.0
# 5.021301537474044 +/- 0.0
# 4.835972335577651 +/- 0.0
# 4.635821709845098 +/- 0.0
# 6.1646658435054515 +/- 0.0
# 5.229678000344709 +/- 0.0
# 3.239151179726824 +/- 0.0
# 7.037190296203933 +/- 0.0
# 2.6932886200729245 +/- 0.0
# 3.92157632606562 +/- 0.0

# %% [markdown]
# ### Umbrella-Sampling Pipeline

# %%
import signac
from flow import FlowProject
import numpy as np
import subprocess
import sys
import shutil

compute_pf_mn = 0.7
compute_pf_mx = 0.9
samplename = '/sample.gsd'
FL_equilibrum_steps = 2e4
FL_sampling_steps = 3e4
seeds = [12345]

class FreeEnergy(FlowProject):
    pass


project = signac.get_project("Solid")
for job in project:
    if 'pf' not in job.sp:
        shutil.rmtree(job.path)

# %% [markdown]
#  $Umbrella-Sampling$ 方法是计算样品非平衡态自由能的一种方式。工作流如下：前提，由二完成样品的制作。首先，给定要计算的样品的密度区间，选出要计算的样品。其次，给定反应坐标（或称选择序参量）。然后，对每个 job 样品又创建了自己的 Umbrella Project，并提交到计算集群。接着，等待所有 job 完成，最后汇总结果，得到样品的绝对自由能。
#
#  这里实际上在 Solid Project 的特定 job 中，又创建了新的 Umbrella Project 。

# %%
import signac
from flow import FlowProject
import numpy as np

path = os.getcwd()
compute_pf_mn = 0.80
compute_pf_mx = 0.85
samplename = '/sample.gsd'
n_window = 30
ks = [1e3] * n_window
windows = np.linspace(0,1, n_window)
seeds = [12345]
orderparameterstr = "hcpmc.OrderParameter.OrderParameter2DPsi6_minusPsi4()"
sampling_steps = 5e4
simtrials = 50
equili_strict = 20

class Umbrella(FlowProject):
    pass


project = signac.get_project("Solid")

for job in project:
    if job.sp.pf > compute_pf_mn - 1e-3 and job.sp.pf < compute_pf_mx + 1e-3:
        proj = Umbrella.init_project(job.path +"/Umbrella")
        for k, window in zip(ks, windows):
            for seed in seeds:
                sp = dict(k=k, window=window, seed=seed)
                proj.open_job(sp).init()  # open a job with the specified statepoint
        
        f = open(job.path + "/Umbrella/project.py", "w")
        code_lines = [
            "from flow import FlowProject\n",
            "import sys\n",
            "import os\n",
            f'sys.path.append("{path}")\n',
            "import hcpmc\n",
            f'samplename = os.getcwd() + "/..{samplename}"\n',
            f"factory = {factorystr}\n",
            f"orderparameter = {orderparameterstr}\n"
            f"sampling_steps = int({sampling_steps})\n",
            f"simtrials = int({simtrials})\n",
            f"equili_strict = int({equili_strict})\n",
            
            "class Umbrella(FlowProject):\n",
            "    pass\n",
            "@Umbrella.label\n",
            "def finish(job):\n",
            '    return "done" in job.document\n',
            "@Umbrella.post(finish)\n",
            "@Umbrella.operation(directives={'memory': '1g', 'walltime': 15})\n",
            "def sample(job):\n",
            "    with job:\n",
            "        H = hcpmc.umbrella.UmbrellaSampling.BiasSampling(samplename,factory,job.sp.k,job.sp.window,sampling_steps)\n",
            "        H.calculate(orderparameter,simtrials,equili_strict,job.sp.seed)\n",
            '        job.doc["done"] = 1\n',
            'if __name__ == "__main__":\n',
            "    Umbrella().main()\n",
        ]
        f.writelines(code_lines)
        f.flush()
# Out:
# /home/jwang/miniforge3/envs/hd5/lib/python3.13/site-packages/synced_collections/numpy_utils.py:46: NumpyConversionWarning: Any numpy types provided will be transparently converted to the closest base Python equivalents.
#   warnings.warn(NUMPY_CONVERSION_WARNING, NumpyConversionWarning)
# /home/jwang/miniforge3/envs/hd5/lib/python3.13/site-packages/synced_collections/numpy_utils.py:46: NumpyConversionWarning: Any numpy types provided will be transparently converted to the closest base Python equivalents.
#   warnings.warn(NUMPY_CONVERSION_WARNING, NumpyConversionWarning)
# /home/jwang/miniforge3/envs/hd5/lib/python3.13/site-packages/synced_collections/numpy_utils.py:46: NumpyConversionWarning: Any numpy types provided will be transparently converted to the closest base Python equivalents.
#   warnings.warn(NUMPY_CONVERSION_WARNING, NumpyConversionWarning)
# /home/jwang/miniforge3/envs/hd5/lib/python3.13/site-packages/synced_collections/numpy_utils.py:46: NumpyConversionWarning: Any numpy types provided will be transparently converted to the closest base Python equivalents.
#   warnings.warn(NUMPY_CONVERSION_WARNING, NumpyConversionWarning)
# /home/jwang/miniforge3/envs/hd5/lib/python3.13/site-packages/synced_collections/numpy_utils.py:46: NumpyConversionWarning: Any numpy types provided will be transparently converted to the closest base Python equivalents.
#   warnings.warn(NUMPY_CONVERSION_WARNING, NumpyConversionWarning)
# /home/jwang/miniforge3/envs/hd5/lib/python3.13/site-packages/synced_collections/numpy_utils.py:46: NumpyConversionWarning: Any numpy types provided will be transparently converted to the closest base Python equivalents.
#   warnings.warn(NUMPY_CONVERSION_WARNING, NumpyConversionWarning)

# %%
import signac
from flow import FlowProject
import numpy as np
import os

project = signac.get_project("Solid")
for job in project:
    if job.sp.pf > compute_pf_mn - 1e-3 and job.sp.pf < compute_pf_mx + 1e-3:
        lines = [
            "#!/bin/bash\n",
            "cd ",
            job.path,
            "/Umbrella\n",
            "python3 project.py submit -o sample",
        ]
        with open("submit.sh", "w") as f:
            f.writelines(lines)
        # !bash submit.sh
os.remove("submit.sh")
# Out:
# Querying scheduler...
# Submitting cluster job 'Umbrella/e29921e5df2ad751e3fa9a5aad55a8cd/sample/85316906e0f4674ac3f46809206427cf':
#  - Group: sample(e29921e5df2ad751e3fa9a5aad55a8cd)
# Submitting cluster job 'Umbrella/4e61625554859082c6757dec0d147ce1/sample/3ba49ac7cf9233e82d47cdab69bc416f':
#  - Group: sample(4e61625554859082c6757dec0d147ce1)
# Submitting cluster job 'Umbrella/cb951a44422f22ae31d0699d59686739/sample/ec3bf3c8f73649c774ceb0a37045979f':
#  - Group: sample(cb951a44422f22ae31d0699d59686739)
# Submitting cluster job 'Umbrella/ca429de34c0bc815417abdc63f28a71e/sample/943eb029697e1af72a6557390e3ad185':
#  - Group: sample(ca429de34c0bc815417abdc63f28a71e)
# Submitting cluster job 'Umbrella/4f9b1f378d0984373f5983c997609f5a/sample/c15aa26205ad5305274a9d78e34b5539':
#  - Group: sample(4f9b1f378d0984373f5983c997609f5a)
# Submitting cluster job 'Umbrella/62c44a83318b3e271af6388072bdc131/sample/62308f9778b305c47f216f433b0e7b59':
#  - Group: sample(62c44a83318b3e271af6388072bdc131)
# Submitting cluster job 'Umbrella/9e641d65a2697020ea10dd603e17eca5/sample/daa84f07f11591a0e1ab3258db114974':
#  - Group: sample(9e641d65a2697020ea10dd603e17eca5)
# Submitting cluster job 'Umbrella/d869cf72da825e570ae44b8635403ce4/sample/ac38d60b7a119d3997de5e300f43bfc7':
#  - Group: sample(d869cf72da825e570ae44b8635403ce4)
# Submitting cluster job 'Umbrella/b3746408ff2ffb9f7a80306bc91ac02a/sample/b7afd116c1045034bcbfbf394e6a3d5d':
#  - Group: sample(b3746408ff2ffb9f7a80306bc91ac02a)
# Submitting cluster job 'Umbrella/7c8e959eb1118ef9e0b174a63481c470/sample/bb08d4749cee712c37ce7e0a77dcbdf9':
#  - Group: sample(7c8e959eb1118ef9e0b174a63481c470)
# Submitting cluster job 'Umbrella/f83402762bdd71f01122a66bc3bf0c75/sample/d9d35610a475573fb602faecb6cefc8b':
#  - Group: sample(f83402762bdd71f01122a66bc3bf0c75)
# Submitting cluster job 'Umbrella/924c1496abdd91444ac5561d9c9827ee/sample/775dcde9800c986e4cd5ccd271d12066':
#  - Group: sample(924c1496abdd91444ac5561d9c9827ee)
# Submitting cluster job 'Umbrella/6d80b3dc4507ef18f5ce72858d05d575/sample/36b4cf7b07e8aac2a55e3eb3c16f81a6':
#  - Group: sample(6d80b3dc4507ef18f5ce72858d05d575)
# Submitting cluster job 'Umbrella/19698fb48c46a103e29e33e7a2257fe6/sample/d6802b8e82d81ef7cbf5632389993996':
#  - Group: sample(19698fb48c46a103e29e33e7a2257fe6)
# Submitting cluster job 'Umbrella/84050a69c532710c04951b3d6d0d10a8/sample/f52548d58d7fb4018482f1173a8dff6f':
#  - Group: sample(84050a69c532710c04951b3d6d0d10a8)
# Submitting cluster job 'Umbrella/9b9604b40c270218b4aecc3393f1c253/sample/844a3da6ec2b3df3d26dd4ee88dddecd':
#  - Group: sample(9b9604b40c270218b4aecc3393f1c253)
# Submitting cluster job 'Umbrella/3c6493fb87379e462b615cdb731dbd5f/sample/b41b2bd3f82270cb59b5e3e4d8a90e56':
#  - Group: sample(bec1d6968893d6e5de2ed3fdbd942a05)
# Submitting cluster job 'Umbrella/b07d7bbe9aaebef9e50c85a59ea26876/sample/420aeb581e37406e8282a65ac7e34a12':
#  - Group: sample(b07d7bbe9aaebef9e50c85a59ea26876)
# Submitting cluster job 'Umbrella/b53b12dad808c4c9058b63eaf0a98834/sample/997a6fc0f52353a5c2a6d1a97a1a77b0':
#  - Group: sample(b53b12dad808c4c9058b63eaf0a98834)
# Submitting cluster job 'Umbrella/ed80aee1d03abf511b6671ecb872765a/sample/14a39ee48d7a3b36cf2cf4d630f21b2f':
#  - Group: sample(ed80aee1d03abf511b6671ecb872765a)
# Submitting cluster job 'Umbrella/62c2f98e187c3782a2a225536b6862cd/sample/20c543a506d5935285194bfd241e3383':
#  - Group: sample(62c2f98e187c3782a2a225536b6862cd)
# Submitting cluster job 'Umbrella/ed39ff63128cf8d5059a4d5c0b33f059/sample/e2ede46e47818e78ffa740dfe5d62eb4':
#  - Group: sample(ed39ff63128cf8d5059a4d5c0b33f059)
# Submitting cluster job 'Umbrella/a0b643e507f6c7e41f3e3cb1e0c978e2/sample/eaa1f208ea2ea9e4b08a1648fa312ecb':
#  - Group: sample(a0b643e507f6c7e41f3e3cb1e0c978e2)
# Submitting cluster job 'Umbrella/21a429f662bb1ccd35ad0f048ef5db78/sample/2c353af811caf62048c98af7ed766a2c':
#  - Group: sample(21a429f662bb1ccd35ad0f048ef5db78)
# Submitting cluster job 'Umbrella/1e4dce5f51ce053ab90c225fcf997fe7/sample/c20f673f06fddbed20043112e0b3e67a':
#  - Group: sample(1e4dce5f51ce053ab90c225fcf997fe7)
# Submitting cluster job 'Umbrella/24f66f7ba98ee153edc65d67c735a75a/sample/109bcf06515e27a36f91ae439ece58a6':
#  - Group: sample(24f66f7ba98ee153edc65d67c735a75a)
# Submitting cluster job 'Umbrella/0a7c9272a309fd1eac3e3a59e7f094f0/sample/50af5f2ae495bc7d5e333bdb5e19f5f6':
#  - Group: sample(0a7c9272a309fd1eac3e3a59e7f094f0)
# Submitting cluster job 'Umbrella/f09b226fc3d68945ea9bec5e4399a865/sample/e4e0c6a430d424d71c8066fab7a388aa':
#  - Group: sample(f09b226fc3d68945ea9bec5e4399a865)
# Submitting cluster job 'Umbrella/76f7cb6430b205f7bf3e3b3cab0e75f6/sample/04b3a5c99b36ff5109aee3422b181bfa':
#  - Group: sample(76f7cb6430b205f7bf3e3b3cab0e75f6)
# Submitting cluster job 'Umbrella/b52f52904e848638112494459e5b3798/sample/6252ae528c8f5967c337a19686ffe895':
#  - Group: sample(b52f52904e848638112494459e5b3798)
# Submitting cluster job 'Umbrella/9ae279a29a1e1783a41b3265e909323e/sample/27fe253e0ed6333e29b220a7d01265b1':
#  - Group: sample(9ae279a29a1e1783a41b3265e909323e)
# Submitting cluster job 'Umbrella/fb205c658618192bfd105ca3dbe35267/sample/848e973466be42c73770b261a0451d09':
#  - Group: sample(fb205c658618192bfd105ca3dbe35267)
# Submitting cluster job 'Umbrella/f455e1e1f0a1ce2c3fab5b1775dded43/sample/1cbd71d7d271a360ccf1348371dae5b9':
#  - Group: sample(f455e1e1f0a1ce2c3fab5b1775dded43)
# Submitting cluster job 'Umbrella/2cf1462a07d613d2a4aa45ca64d20a0d/sample/7afae7dfc62cacf6a2215019fecdf2ad':
#  - Group: sample(2cf1462a07d613d2a4aa45ca64d20a0d)
# Submitting cluster job 'Umbrella/f2f643cebe0cb18c5dd528483006e666/sample/9b886a3cad3cd7d28cbc9589df81a919':
#  - Group: sample(f2f643cebe0cb18c5dd528483006e666)
# Submitting cluster job 'Umbrella/d3c41bc6746f21a8b86ac81af4ab80fb/sample/4857d0cfdb1741920e2ed59769b8300b':
#  - Group: sample(d3c41bc6746f21a8b86ac81af4ab80fb)
# Submitting cluster job 'Umbrella/4f6e6aa7f56466a12ee8fbc37b36faf4/sample/7ce6e7f77e322d351b7afe92bc15679d':
#  - Group: sample(4f6e6aa7f56466a12ee8fbc37b36faf4)
# Submitting cluster job 'Umbrella/13779f0c904fc7cae89b2c35892bdac2/sample/99451dc098f716c9aa999346b9f6f748':
#  - Group: sample(13779f0c904fc7cae89b2c35892bdac2)
# Submitting cluster job 'Umbrella/e053819fba08ce5410eeeb7d11945d3a/sample/ae73d244da8b3327d31d755ca9ed6fe2':
#  - Group: sample(e053819fba08ce5410eeeb7d11945d3a)
# Submitting cluster job 'Umbrella/3ff740726bb1a652dddcd1263c0c270f/sample/7983c2cf5c37510b71f51bdce501f215':
#  - Group: sample(3ff740726bb1a652dddcd1263c0c270f)
# Submitting cluster job 'Umbrella/5d603cec72f9fa42d961437be08975e2/sample/beff371c2702baef1957a952e56a1cb5':
#  - Group: sample(5d603cec72f9fa42d961437be08975e2)
# Submitting cluster job 'Umbrella/15e53f5b21243e8ccea7f2b66a05b4a2/sample/4d58430ec5b2ed8c6f1832b30081accf':
#  - Group: sample(15e53f5b21243e8ccea7f2b66a05b4a2)
# Submitting cluster job 'Umbrella/e14741f1bf2b462c41adb5947c49a3e9/sample/3326e145b4e661c349767cb3cdea21bf':
#  - Group: sample(e14741f1bf2b462c41adb5947c49a3e9)
# Submitting cluster job 'Umbrella/16b0c40782b1b81ab8155659f367fed0/sample/ebf3ec170b6362ebac7758bb5d47230f':
#  - Group: sample(16b0c40782b1b81ab8155659f367fed0)
# Querying scheduler...
# Submitting cluster job 'Umbrella/e29921e5df2ad751e3fa9a5aad55a8cd/sample/fb17fd1645203c33677c7af40424198c':
#  - Group: sample(e29921e5df2ad751e3fa9a5aad55a8cd)
# Submitting cluster job 'Umbrella/4e61625554859082c6757dec0d147ce1/sample/bb1a2bb9019b10d103040b5506f82778':
#  - Group: sample(4e61625554859082c6757dec0d147ce1)
# Submitting cluster job 'Umbrella/cb951a44422f22ae31d0699d59686739/sample/48c4846820c61389609db027c0ba3385':
#  - Group: sample(cb951a44422f22ae31d0699d59686739)
# Submitting cluster job 'Umbrella/ca429de34c0bc815417abdc63f28a71e/sample/8783afba91bb5e3280131c7fd2c55794':
#  - Group: sample(ca429de34c0bc815417abdc63f28a71e)
# Submitting cluster job 'Umbrella/4f9b1f378d0984373f5983c997609f5a/sample/e71345617f455e84cda62472bb9cab5e':
#  - Group: sample(4f9b1f378d0984373f5983c997609f5a)
# Submitting cluster job 'Umbrella/62c44a83318b3e271af6388072bdc131/sample/9b639e9c43bc285fd1871f522850f30e':
#  - Group: sample(62c44a83318b3e271af6388072bdc131)
# Submitting cluster job 'Umbrella/9e641d65a2697020ea10dd603e17eca5/sample/81e386ce300ff9ac98abb5b6b2a6fcb2':
#  - Group: sample(9e641d65a2697020ea10dd603e17eca5)
# Submitting cluster job 'Umbrella/d869cf72da825e570ae44b8635403ce4/sample/727ac1c5573188444f2cd210e17c9069':
#  - Group: sample(d869cf72da825e570ae44b8635403ce4)
# Submitting cluster job 'Umbrella/b3746408ff2ffb9f7a80306bc91ac02a/sample/3d37ec0d8fe6e6934b035b87d7e85981':
#  - Group: sample(b3746408ff2ffb9f7a80306bc91ac02a)
# Submitting cluster job 'Umbrella/7c8e959eb1118ef9e0b174a63481c470/sample/3351e81d6a07d83658628951df3c59dc':
#  - Group: sample(7c8e959eb1118ef9e0b174a63481c470)
# Submitting cluster job 'Umbrella/f83402762bdd71f01122a66bc3bf0c75/sample/f1abffa828e2eb2b49275d4a848323fa':
#  - Group: sample(f83402762bdd71f01122a66bc3bf0c75)
# Submitting cluster job 'Umbrella/924c1496abdd91444ac5561d9c9827ee/sample/2804d65b780abf4b19f7a5b7a3daad94':
#  - Group: sample(924c1496abdd91444ac5561d9c9827ee)
# Submitting cluster job 'Umbrella/6d80b3dc4507ef18f5ce72858d05d575/sample/1bcaa2bf034ca76c2d85e597335eb856':
#  - Group: sample(6d80b3dc4507ef18f5ce72858d05d575)
# Submitting cluster job 'Umbrella/19698fb48c46a103e29e33e7a2257fe6/sample/1c3fe2c97bd2339874f840af075cc854':
#  - Group: sample(19698fb48c46a103e29e33e7a2257fe6)
# Submitting cluster job 'Umbrella/84050a69c532710c04951b3d6d0d10a8/sample/45d6f4fc835046593ff54ab527caf887':
#  - Group: sample(84050a69c532710c04951b3d6d0d10a8)
# Submitting cluster job 'Umbrella/9b9604b40c270218b4aecc3393f1c253/sample/66e79c1004465df03391f8fdb05c6560':
#  - Group: sample(9b9604b40c270218b4aecc3393f1c253)
# Submitting cluster job 'Umbrella/3c6493fb87379e462b615cdb731dbd5f/sample/222f93df0b6078d99bd02e7969135b2f':
#  - Group: sample(3c6493fb87379e462b615cdb731dbd5f)
# Submitting cluster job 'Umbrella/d53fa4016ba220ea1e8459be55113a40/sample/44d490194ed2ee6e81b0d3923c7e695d':
#  - Group: sample(d53fa4016ba220ea1e8459be55113a40)
# Submitting cluster job 'Umbrella/97eba295d017d88a9440a41e07249e50/sample/1da3c21423d435c0c8bd647e838c02fb':
#  - Group: sample(97eba295d017d88a9440a41e07249e50)
# Submitting cluster job 'Umbrella/201c80b5b8858b1b11ed32fcbe6c836f/sample/be83b38d461292968a835c3d2f0698a1':
#  - Group: sample(201c80b5b8858b1b11ed32fcbe6c836f)
#  - Group: sample(ed80aee1d03abf511b6671ecb872765a)
# Submitting cluster job 'Umbrella/62c2f98e187c3782a2a225536b6862cd/sample/dba0e534682bbd8922b190cc22275775':
#  - Group: sample(62c2f98e187c3782a2a225536b6862cd)
# Submitting cluster job 'Umbrella/ed39ff63128cf8d5059a4d5c0b33f059/sample/a2b5dc5ee58e35302e73e75777f32eb9':
#  - Group: sample(ed39ff63128cf8d5059a4d5c0b33f059)
# Submitting cluster job 'Umbrella/a0b643e507f6c7e41f3e3cb1e0c978e2/sample/86723e2b0a2182e8c793660e45cf3cd8':
#  - Group: sample(a0b643e507f6c7e41f3e3cb1e0c978e2)
# Submitting cluster job 'Umbrella/21a429f662bb1ccd35ad0f048ef5db78/sample/6205e1dff3bc96858aefa2554cf5e3da':
#  - Group: sample(21a429f662bb1ccd35ad0f048ef5db78)
# Submitting cluster job 'Umbrella/1e4dce5f51ce053ab90c225fcf997fe7/sample/045640d93e44781ca5bf55b41149902a':
#  - Group: sample(1e4dce5f51ce053ab90c225fcf997fe7)
# Submitting cluster job 'Umbrella/24f66f7ba98ee153edc65d67c735a75a/sample/45d09bf13df712a35de4f4cf63b765bf':
#  - Group: sample(24f66f7ba98ee153edc65d67c735a75a)
# Submitting cluster job 'Umbrella/0a7c9272a309fd1eac3e3a59e7f094f0/sample/ae2d3e088c5b097d2ecc203d01a8e9c3':
#  - Group: sample(0a7c9272a309fd1eac3e3a59e7f094f0)
# Submitting cluster job 'Umbrella/f09b226fc3d68945ea9bec5e4399a865/sample/817983a717dafdf74d840c43742b8ee3':
#  - Group: sample(f09b226fc3d68945ea9bec5e4399a865)
# Submitting cluster job 'Umbrella/76f7cb6430b205f7bf3e3b3cab0e75f6/sample/9e959b1b9eedc02a9c1007f232aff49d':
#  - Group: sample(76f7cb6430b205f7bf3e3b3cab0e75f6)
# Submitting cluster job 'Umbrella/b52f52904e848638112494459e5b3798/sample/d7c539c263b43a299f81db1709dce4b2':
#  - Group: sample(b52f52904e848638112494459e5b3798)
# Submitting cluster job 'Umbrella/9ae279a29a1e1783a41b3265e909323e/sample/6563298a20315c91090b5a3228b3b0f0':
#  - Group: sample(9ae279a29a1e1783a41b3265e909323e)
# Submitting cluster job 'Umbrella/fb205c658618192bfd105ca3dbe35267/sample/e7dd4518721bcc50fce3bd5e0bc8481f':
#  - Group: sample(fb205c658618192bfd105ca3dbe35267)
# Submitting cluster job 'Umbrella/f455e1e1f0a1ce2c3fab5b1775dded43/sample/4e1f3d0c1136820ab12a922eb6ef4909':
#  - Group: sample(f455e1e1f0a1ce2c3fab5b1775dded43)
# Submitting cluster job 'Umbrella/2cf1462a07d613d2a4aa45ca64d20a0d/sample/15fe2678072bfc0b28050ab9bbcf59d2':
#  - Group: sample(2cf1462a07d613d2a4aa45ca64d20a0d)
# Submitting cluster job 'Umbrella/f2f643cebe0cb18c5dd528483006e666/sample/a1b52c2dbbcc74f0b4de84def0e61ecc':
#  - Group: sample(f2f643cebe0cb18c5dd528483006e666)
# Submitting cluster job 'Umbrella/d3c41bc6746f21a8b86ac81af4ab80fb/sample/98bbfe9001cbbfd5d634961490e40742':
#  - Group: sample(d3c41bc6746f21a8b86ac81af4ab80fb)
# Submitting cluster job 'Umbrella/4f6e6aa7f56466a12ee8fbc37b36faf4/sample/5a39c9c061b83bfa3e653e2c13610f24':
#  - Group: sample(4f6e6aa7f56466a12ee8fbc37b36faf4)
# Submitting cluster job 'Umbrella/13779f0c904fc7cae89b2c35892bdac2/sample/74a316d5f00afdde47a11970bfec512a':
#  - Group: sample(13779f0c904fc7cae89b2c35892bdac2)
# Submitting cluster job 'Umbrella/e053819fba08ce5410eeeb7d11945d3a/sample/d2db554055871a8b6767b3758e18af5e':
#  - Group: sample(e053819fba08ce5410eeeb7d11945d3a)
# Submitting cluster job 'Umbrella/3ff740726bb1a652dddcd1263c0c270f/sample/7adcb80a344e526e5891a0aaf23c182e':
#  - Group: sample(3ff740726bb1a652dddcd1263c0c270f)
# Submitting cluster job 'Umbrella/5d603cec72f9fa42d961437be08975e2/sample/a088ba85f91687eb67c54c2b2111653a':
#  - Group: sample(5d603cec72f9fa42d961437be08975e2)
# Submitting cluster job 'Umbrella/15e53f5b21243e8ccea7f2b66a05b4a2/sample/8caac287778f15a6d469d79c7f05a8cf':
#  - Group: sample(15e53f5b21243e8ccea7f2b66a05b4a2)
# Submitting cluster job 'Umbrella/e14741f1bf2b462c41adb5947c49a3e9/sample/44e94d95bbd831c2df8d48ad5cc374d3':
#  - Group: sample(e14741f1bf2b462c41adb5947c49a3e9)
# Submitting cluster job 'Umbrella/16b0c40782b1b81ab8155659f367fed0/sample/f5778adfb20b45b5b0dc582618113a6d':
#  - Group: sample(16b0c40782b1b81ab8155659f367fed0)
# Querying scheduler...
# Submitting cluster job 'Umbrella/e29921e5df2ad751e3fa9a5aad55a8cd/sample/ec894254bedb120c153d5d970b4d1015':
#  - Group: sample(e29921e5df2ad751e3fa9a5aad55a8cd)
# Submitting cluster job 'Umbrella/4e61625554859082c6757dec0d147ce1/sample/ef02ec702580ccce8fb3812670d17a38':
#  - Group: sample(4e61625554859082c6757dec0d147ce1)
# Submitting cluster job 'Umbrella/cb951a44422f22ae31d0699d59686739/sample/f65ecd0a9c407b0d6637c39a5243afd1':
#  - Group: sample(cb951a44422f22ae31d0699d59686739)
# Submitting cluster job 'Umbrella/ca429de34c0bc815417abdc63f28a71e/sample/1cdaba27354fd581d1c133138d271b52':
#  - Group: sample(ca429de34c0bc815417abdc63f28a71e)
# Submitting cluster job 'Umbrella/4f9b1f378d0984373f5983c997609f5a/sample/169436711fc7e4fcf12e8a846ad402bf':
#  - Group: sample(4f9b1f378d0984373f5983c997609f5a)
# Submitting cluster job 'Umbrella/62c44a83318b3e271af6388072bdc131/sample/2b730b61fca8ec0c10dd1511ac734467':
#  - Group: sample(62c44a83318b3e271af6388072bdc131)
# Submitting cluster job 'Umbrella/9e641d65a2697020ea10dd603e17eca5/sample/f1c08489ed5a6a3e3c150a7478d4782e':
#  - Group: sample(9e641d65a2697020ea10dd603e17eca5)
# Submitting cluster job 'Umbrella/d869cf72da825e570ae44b8635403ce4/sample/74f31c06dfd2779e9fdb5ff941052d8b':
#  - Group: sample(d869cf72da825e570ae44b8635403ce4)
# Submitting cluster job 'Umbrella/b3746408ff2ffb9f7a80306bc91ac02a/sample/71e2b4bf07f86aa8ccb077af2620b71a':
#  - Group: sample(b3746408ff2ffb9f7a80306bc91ac02a)
# Submitting cluster job 'Umbrella/7c8e959eb1118ef9e0b174a63481c470/sample/8a97ecd9ef71c4bd14532298dec3e5d8':
#  - Group: sample(7c8e959eb1118ef9e0b174a63481c470)
# Submitting cluster job 'Umbrella/f83402762bdd71f01122a66bc3bf0c75/sample/7549dc15fdf8ebaf47cde64ba86ce614':
#  - Group: sample(f83402762bdd71f01122a66bc3bf0c75)
# Submitting cluster job 'Umbrella/924c1496abdd91444ac5561d9c9827ee/sample/93b5615fe45a50f65b59186f85d474d2':
#  - Group: sample(924c1496abdd91444ac5561d9c9827ee)
# Submitting cluster job 'Umbrella/6d80b3dc4507ef18f5ce72858d05d575/sample/620f08f5d2b935a342d334120229c02a':
#  - Group: sample(6d80b3dc4507ef18f5ce72858d05d575)
# Submitting cluster job 'Umbrella/19698fb48c46a103e29e33e7a2257fe6/sample/0384d9fd688a26208993c0785e4275d1':
#  - Group: sample(19698fb48c46a103e29e33e7a2257fe6)
# Submitting cluster job 'Umbrella/84050a69c532710c04951b3d6d0d10a8/sample/3717670ffcf99d32e7eceb483f3ee893':
#  - Group: sample(84050a69c532710c04951b3d6d0d10a8)
# Submitting cluster job 'Umbrella/9b9604b40c270218b4aecc3393f1c253/sample/0e828540122590998616bf6c01972ab8':
#  - Group: sample(9b9604b40c270218b4aecc3393f1c253)
# Submitting cluster job 'Umbrella/3c6493fb87379e462b615cdb731dbd5f/sample/0fdf1611ebfd24687c4d89f35eca3f25':
#  - Group: sample(3c6493fb87379e462b615cdb731dbd5f)
# Submitting cluster job 'Umbrella/d53fa4016ba220ea1e8459be55113a40/sample/0e70c168bdd213580ffd566e0297a0f2':
#  - Group: sample(d53fa4016ba220ea1e8459be55113a40)
# Submitting cluster job 'Umbrella/97eba295d017d88a9440a41e07249e50/sample/47c1698677524b8dee751e5d7e80a3b6':
#  - Group: sample(97eba295d017d88a9440a41e07249e50)
# Submitting cluster job 'Umbrella/201c80b5b8858b1b11ed32fcbe6c836f/sample/700bfab8b96907aeb7320e1d1bcbc640':
#  - Group: sample(201c80b5b8858b1b11ed32fcbe6c836f)
# Submitting cluster job 'Umbrella/6462821c4683b3449cf4ff66cf7f56b1/sample/4a58a0dd310e29b5c997e615cb4822a8':
#  - Group: sample(6462821c4683b3449cf4ff66cf7f56b1)
# Submitting cluster job 'Umbrella/29ce9ce8ff07a5cc72c10586f1951ef8/sample/615dbdb360225b8ed1d039d219a6bf94':
#  - Group: sample(29ce9ce8ff07a5cc72c10586f1951ef8)
# Submitting cluster job 'Umbrella/fd9ce3b790b49d1027336a9020d17465/sample/d70f68bb43e6bcfd43f4ce5676976454':
#  - Group: sample(fd9ce3b790b49d1027336a9020d17465)
# Submitting cluster job 'Umbrella/f74f48e642287baceb491d66c3c420b9/sample/0f1fc8895548f05d5170392032b69eb3':
#  - Group: sample(f74f48e642287baceb491d66c3c420b9)
# Submitting cluster job 'Umbrella/fbe82af3b80c2a17cc9dde978888a33e/sample/df5657c1dc9c6407ab881f9aa60fc34d':
#  - Group: sample(fbe82af3b80c2a17cc9dde978888a33e)
# Submitting cluster job 'Umbrella/3b16ee7b1b6f8e189b6771cab72064d3/sample/000eed9a729dd97b43997e85c8b0672d':
#  - Group: sample(3b16ee7b1b6f8e189b6771cab72064d3)
# Submitting cluster job 'Umbrella/853b3df6c41c8d006c2f817d0aca7a5a/sample/cec23a92eaacee7a06b31c99c98cfde3':
#  - Group: sample(853b3df6c41c8d006c2f817d0aca7a5a)
# Submitting cluster job 'Umbrella/2788cc6991afadbef714e9aa219d8c79/sample/8f5ee4cb0003486e0bc396816353baf8':
#  - Group: sample(2788cc6991afadbef714e9aa219d8c79)
# Submitting cluster job 'Umbrella/ceedf28c659d31e6304c94974279b71c/sample/2092c93c297629dce184f3508836eaef':
#  - Group: sample(ceedf28c659d31e6304c94974279b71c)
# Submitting cluster job 'Umbrella/38d19054da55a15263c8c94758ff60e2/sample/8b595cb0f8dc7722d6a3a189b7fc5cf4':
#  - Group: sample(38d19054da55a15263c8c94758ff60e2)
# Submitting cluster job 'Umbrella/e3f8b3bad86a5c17d16e20b3c3aed92e/sample/fdd75b296c877acf6a1c1ef1e5152456':
#  - Group: sample(e3f8b3bad86a5c17d16e20b3c3aed92e)
# Submitting cluster job 'Umbrella/43e20cc5e137ed62723446b8ff0a1d7a/sample/a7ef97ce45c7bd8254b3fe579299f97c':
#  - Group: sample(43e20cc5e137ed62723446b8ff0a1d7a)
# Submitting cluster job 'Umbrella/bec1d6968893d6e5de2ed3fdbd942a05/sample/11e1da57c72a839421d8e3b220c83eeb':
#  - Group: sample(bec1d6968893d6e5de2ed3fdbd942a05)
# Submitting cluster job 'Umbrella/b07d7bbe9aaebef9e50c85a59ea26876/sample/b6c1cac2445e294cf2f42c0e4ce9d337':
#  - Group: sample(b07d7bbe9aaebef9e50c85a59ea26876)
# Submitting cluster job 'Umbrella/b53b12dad808c4c9058b63eaf0a98834/sample/7e5cef1ab150d7f8c517206b68be12b6':
#  - Group: sample(b53b12dad808c4c9058b63eaf0a98834)
# Submitting cluster job 'Umbrella/ed80aee1d03abf511b6671ecb872765a/sample/2e7c7cdf887e716b8a93fd2bcaaf3ae9':
#  - Group: sample(ed80aee1d03abf511b6671ecb872765a)
# Submitting cluster job 'Umbrella/62c2f98e187c3782a2a225536b6862cd/sample/609aa8f7703e8774aa4a2de1844b9393':
#  - Group: sample(62c2f98e187c3782a2a225536b6862cd)
# Submitting cluster job 'Umbrella/ed39ff63128cf8d5059a4d5c0b33f059/sample/efbd89b63a04774cd0a9aef99edb438d':
#  - Group: sample(ed39ff63128cf8d5059a4d5c0b33f059)
# Submitting cluster job 'Umbrella/a0b643e507f6c7e41f3e3cb1e0c978e2/sample/f8c57d6d909d25d97d3f623e7d657c3d':
# Submitting cluster job 'Umbrella/e053819fba08ce5410eeeb7d11945d3a/sample/d29651e0c773a6c16307419ad6032903':
#  - Group: sample(e053819fba08ce5410eeeb7d11945d3a)
# Submitting cluster job 'Umbrella/3ff740726bb1a652dddcd1263c0c270f/sample/cffa6187e20061d370b106e46cf2ecff':
#  - Group: sample(3ff740726bb1a652dddcd1263c0c270f)
# Submitting cluster job 'Umbrella/5d603cec72f9fa42d961437be08975e2/sample/ce6eef37d0aa1f5d4d933ec48cc1caa7':
#  - Group: sample(5d603cec72f9fa42d961437be08975e2)
# Submitting cluster job 'Umbrella/15e53f5b21243e8ccea7f2b66a05b4a2/sample/f7229d1b61b37fe490ff1aa5e14b6bb5':
#  - Group: sample(15e53f5b21243e8ccea7f2b66a05b4a2)
# Submitting cluster job 'Umbrella/e14741f1bf2b462c41adb5947c49a3e9/sample/5c254e5946bf62c3574648f70778d3c3':
#  - Group: sample(e14741f1bf2b462c41adb5947c49a3e9)
# Submitting cluster job 'Umbrella/16b0c40782b1b81ab8155659f367fed0/sample/ea87680559333f0dbbc8fda6354bb7d6':
#  - Group: sample(16b0c40782b1b81ab8155659f367fed0)
# Querying scheduler...
# Submitting cluster job 'Umbrella/e29921e5df2ad751e3fa9a5aad55a8cd/sample/b59acef69fdb49088cb1f51396d81e83':
#  - Group: sample(e29921e5df2ad751e3fa9a5aad55a8cd)
# Submitting cluster job 'Umbrella/4e61625554859082c6757dec0d147ce1/sample/63e8e20a545d064a597cc14ef7eff5a3':
#  - Group: sample(4e61625554859082c6757dec0d147ce1)
# Submitting cluster job 'Umbrella/cb951a44422f22ae31d0699d59686739/sample/fb69f7700dec4168d938750c978f40a0':
#  - Group: sample(cb951a44422f22ae31d0699d59686739)
# Submitting cluster job 'Umbrella/ca429de34c0bc815417abdc63f28a71e/sample/129748b24ae75733d0a7acc2d3a076a6':
#  - Group: sample(ca429de34c0bc815417abdc63f28a71e)
# Submitting cluster job 'Umbrella/4f9b1f378d0984373f5983c997609f5a/sample/d59ad84a13fdaa064c845e7b63f3870e':
#  - Group: sample(4f9b1f378d0984373f5983c997609f5a)
# Submitting cluster job 'Umbrella/62c44a83318b3e271af6388072bdc131/sample/a26d7445751215b0ef5cd6b36d4382ca':
#  - Group: sample(62c44a83318b3e271af6388072bdc131)
# Submitting cluster job 'Umbrella/9e641d65a2697020ea10dd603e17eca5/sample/2b9e87d1f38a7e84101680e360015c97':
#  - Group: sample(9e641d65a2697020ea10dd603e17eca5)
# Submitting cluster job 'Umbrella/d869cf72da825e570ae44b8635403ce4/sample/07169d9dd60fd2790f4d2d0367ee5317':
#  - Group: sample(d869cf72da825e570ae44b8635403ce4)
# Submitting cluster job 'Umbrella/b3746408ff2ffb9f7a80306bc91ac02a/sample/433bd737cd9068f1d56c3cb446ce96a7':
#  - Group: sample(b3746408ff2ffb9f7a80306bc91ac02a)
# Submitting cluster job 'Umbrella/7c8e959eb1118ef9e0b174a63481c470/sample/873be13b6611b41a3c163ff58e5e9aae':
#  - Group: sample(7c8e959eb1118ef9e0b174a63481c470)
# Submitting cluster job 'Umbrella/f83402762bdd71f01122a66bc3bf0c75/sample/a454d98a836c1d8d57870471c79d2cdf':
#  - Group: sample(f83402762bdd71f01122a66bc3bf0c75)
# Submitting cluster job 'Umbrella/924c1496abdd91444ac5561d9c9827ee/sample/cbe31301063d3d3b54c5a3ec3f4ca8c9':
#  - Group: sample(924c1496abdd91444ac5561d9c9827ee)
# Submitting cluster job 'Umbrella/6d80b3dc4507ef18f5ce72858d05d575/sample/fa1c899b63d4cbf6c90f07dc068a11c0':
#  - Group: sample(6d80b3dc4507ef18f5ce72858d05d575)
# Submitting cluster job 'Umbrella/19698fb48c46a103e29e33e7a2257fe6/sample/b83c31d9d31cd62ec9e49e7416bed056':
#  - Group: sample(19698fb48c46a103e29e33e7a2257fe6)
# Submitting cluster job 'Umbrella/84050a69c532710c04951b3d6d0d10a8/sample/928de024cb2c01a45b4ba1848c5a981f':
#  - Group: sample(84050a69c532710c04951b3d6d0d10a8)
# Submitting cluster job 'Umbrella/9b9604b40c270218b4aecc3393f1c253/sample/7ac0096e3763b6bbb08c5d36ab83dd25':
#  - Group: sample(9b9604b40c270218b4aecc3393f1c253)
# Submitting cluster job 'Umbrella/3c6493fb87379e462b615cdb731dbd5f/sample/ecb94873c3ad28637359c8433c4c227b':
#  - Group: sample(3c6493fb87379e462b615cdb731dbd5f)
# Submitting cluster job 'Umbrella/d53fa4016ba220ea1e8459be55113a40/sample/cc51404c3c0593a5c9e46df68b2842b6':
#  - Group: sample(d53fa4016ba220ea1e8459be55113a40)
# Submitting cluster job 'Umbrella/97eba295d017d88a9440a41e07249e50/sample/6985def75c396c3cd6d62714643bbb17':
#  - Group: sample(97eba295d017d88a9440a41e07249e50)
# Submitting cluster job 'Umbrella/201c80b5b8858b1b11ed32fcbe6c836f/sample/89df14eb13fa5873aabd7c612cf3e6b6':
#  - Group: sample(201c80b5b8858b1b11ed32fcbe6c836f)
# Submitting cluster job 'Umbrella/6462821c4683b3449cf4ff66cf7f56b1/sample/5d784797df52c8889dbc17e29fecd71e':
#  - Group: sample(6462821c4683b3449cf4ff66cf7f56b1)
# Submitting cluster job 'Umbrella/29ce9ce8ff07a5cc72c10586f1951ef8/sample/ae02f09f21fb4376fa178212ab281af5':
#  - Group: sample(29ce9ce8ff07a5cc72c10586f1951ef8)
# Submitting cluster job 'Umbrella/fd9ce3b790b49d1027336a9020d17465/sample/47a55827357d6dc241c7951323a2b2ff':
#  - Group: sample(fd9ce3b790b49d1027336a9020d17465)
# Submitting cluster job 'Umbrella/f74f48e642287baceb491d66c3c420b9/sample/59d1a010b808d3a9b0a720f79c3a77b4':
#  - Group: sample(f74f48e642287baceb491d66c3c420b9)
# Submitting cluster job 'Umbrella/fbe82af3b80c2a17cc9dde978888a33e/sample/6dd98384aae5133ee597cb331b71714e':
#  - Group: sample(fbe82af3b80c2a17cc9dde978888a33e)
# Submitting cluster job 'Umbrella/3b16ee7b1b6f8e189b6771cab72064d3/sample/d629d009d5ce45e1bb8bb0489f28b4c9':
#  - Group: sample(3b16ee7b1b6f8e189b6771cab72064d3)
#  - Group: sample(15e53f5b21243e8ccea7f2b66a05b4a2)
# Submitting cluster job 'Umbrella/e14741f1bf2b462c41adb5947c49a3e9/sample/3339181344666270fae437ff2ec8d13d':
#  - Group: sample(e14741f1bf2b462c41adb5947c49a3e9)
# Submitting cluster job 'Umbrella/16b0c40782b1b81ab8155659f367fed0/sample/598cb901a7f507663160d950796e1d35':
#  - Group: sample(16b0c40782b1b81ab8155659f367fed0)
# Querying scheduler...
# Submitting cluster job 'Umbrella/e29921e5df2ad751e3fa9a5aad55a8cd/sample/c571aeb95fb4273e4fce63e5c150ee4a':
#  - Group: sample(e29921e5df2ad751e3fa9a5aad55a8cd)
# Submitting cluster job 'Umbrella/4e61625554859082c6757dec0d147ce1/sample/bffe72d7de4bc4fdeca65965ec1af8dc':
#  - Group: sample(4e61625554859082c6757dec0d147ce1)
# Submitting cluster job 'Umbrella/cb951a44422f22ae31d0699d59686739/sample/596618e1e3d43e9ba8c124edd9cbfed2':
#  - Group: sample(cb951a44422f22ae31d0699d59686739)
# Submitting cluster job 'Umbrella/ca429de34c0bc815417abdc63f28a71e/sample/099f1c1340272fd9dc80faf703c0868d':
#  - Group: sample(ca429de34c0bc815417abdc63f28a71e)
# Submitting cluster job 'Umbrella/4f9b1f378d0984373f5983c997609f5a/sample/8321a12348dad6002216e180a4493370':
#  - Group: sample(4f9b1f378d0984373f5983c997609f5a)
# Submitting cluster job 'Umbrella/62c44a83318b3e271af6388072bdc131/sample/2181e3b99471bb40a0e950c7c90faeee':
#  - Group: sample(62c44a83318b3e271af6388072bdc131)
# Submitting cluster job 'Umbrella/9e641d65a2697020ea10dd603e17eca5/sample/12eabcf64dca592bcd07784b8d4d961e':
#  - Group: sample(9e641d65a2697020ea10dd603e17eca5)
# Submitting cluster job 'Umbrella/d869cf72da825e570ae44b8635403ce4/sample/0635e42a8a09471b32cfb5446ba19bb2':
#  - Group: sample(d869cf72da825e570ae44b8635403ce4)
# Submitting cluster job 'Umbrella/b3746408ff2ffb9f7a80306bc91ac02a/sample/111a6618fd02f57d2b04e9be06ae598a':
#  - Group: sample(b3746408ff2ffb9f7a80306bc91ac02a)
# Submitting cluster job 'Umbrella/7c8e959eb1118ef9e0b174a63481c470/sample/0bfe2ab9b54a031d68442c1994cad27f':
#  - Group: sample(7c8e959eb1118ef9e0b174a63481c470)
# Submitting cluster job 'Umbrella/f83402762bdd71f01122a66bc3bf0c75/sample/dc6c2b9f87846eb532bccf1d4fc7541d':
#  - Group: sample(f83402762bdd71f01122a66bc3bf0c75)
# Submitting cluster job 'Umbrella/924c1496abdd91444ac5561d9c9827ee/sample/7504ad007ac22fd4abce311b51240af3':
#  - Group: sample(924c1496abdd91444ac5561d9c9827ee)
# Submitting cluster job 'Umbrella/6d80b3dc4507ef18f5ce72858d05d575/sample/b623baf5ce1c7c0e0a9d26aa0f61f7f2':
#  - Group: sample(6d80b3dc4507ef18f5ce72858d05d575)
# Submitting cluster job 'Umbrella/19698fb48c46a103e29e33e7a2257fe6/sample/510f1bb3b1157f2603f32b6083735951':
#  - Group: sample(19698fb48c46a103e29e33e7a2257fe6)
# Submitting cluster job 'Umbrella/84050a69c532710c04951b3d6d0d10a8/sample/4eed5d331e491afd07876d7e4891983b':
#  - Group: sample(84050a69c532710c04951b3d6d0d10a8)
# Submitting cluster job 'Umbrella/9b9604b40c270218b4aecc3393f1c253/sample/2bcef73bc727f77aad0668be0fa5100b':
#  - Group: sample(9b9604b40c270218b4aecc3393f1c253)
# Submitting cluster job 'Umbrella/3c6493fb87379e462b615cdb731dbd5f/sample/a7aad881ba186bbcbffb550addf74f88':
#  - Group: sample(3c6493fb87379e462b615cdb731dbd5f)
# Submitting cluster job 'Umbrella/d53fa4016ba220ea1e8459be55113a40/sample/2821943dd44a926b7a1cd0fc59bd96db':
#  - Group: sample(d53fa4016ba220ea1e8459be55113a40)
# Submitting cluster job 'Umbrella/97eba295d017d88a9440a41e07249e50/sample/94a41f131f7c65e8e2e19e7409f15771':
#  - Group: sample(97eba295d017d88a9440a41e07249e50)
# Submitting cluster job 'Umbrella/201c80b5b8858b1b11ed32fcbe6c836f/sample/612717ba17c3d2aa96d606041a407b5b':
#  - Group: sample(201c80b5b8858b1b11ed32fcbe6c836f)
# Submitting cluster job 'Umbrella/6462821c4683b3449cf4ff66cf7f56b1/sample/3bdb9b7756f179a1c56018c62d3117f3':
#  - Group: sample(6462821c4683b3449cf4ff66cf7f56b1)
# Submitting cluster job 'Umbrella/29ce9ce8ff07a5cc72c10586f1951ef8/sample/7a4a8085603f7e43288e62be8d53d1f4':
#  - Group: sample(29ce9ce8ff07a5cc72c10586f1951ef8)
# Submitting cluster job 'Umbrella/fd9ce3b790b49d1027336a9020d17465/sample/5e1a8012359eeacb34310fef2cbc3090':
#  - Group: sample(fd9ce3b790b49d1027336a9020d17465)
# Submitting cluster job 'Umbrella/f74f48e642287baceb491d66c3c420b9/sample/d91ed18dd0e740474363ce53a2170e59':
#  - Group: sample(f74f48e642287baceb491d66c3c420b9)
# Submitting cluster job 'Umbrella/fbe82af3b80c2a17cc9dde978888a33e/sample/5ed1c479b120af32b25836cb5fd5f65f':
#  - Group: sample(fbe82af3b80c2a17cc9dde978888a33e)
# Submitting cluster job 'Umbrella/3b16ee7b1b6f8e189b6771cab72064d3/sample/cb2317e9310e0f61032a32594e567e04':
#  - Group: sample(3b16ee7b1b6f8e189b6771cab72064d3)
# Submitting cluster job 'Umbrella/853b3df6c41c8d006c2f817d0aca7a5a/sample/e43900168fc67bfb20ba841baf98574e':
#  - Group: sample(853b3df6c41c8d006c2f817d0aca7a5a)
# Submitting cluster job 'Umbrella/2788cc6991afadbef714e9aa219d8c79/sample/3baba63f9b52451c36083cf609775178':
#  - Group: sample(2788cc6991afadbef714e9aa219d8c79)
# Submitting cluster job 'Umbrella/ceedf28c659d31e6304c94974279b71c/sample/9259a987da405ff6488b25fef1a191a5':
#  - Group: sample(ceedf28c659d31e6304c94974279b71c)
# Submitting cluster job 'Umbrella/38d19054da55a15263c8c94758ff60e2/sample/e3671c22f410aae7826980b7eeb2ce26':
#  - Group: sample(38d19054da55a15263c8c94758ff60e2)
# Submitting cluster job 'Umbrella/e3f8b3bad86a5c17d16e20b3c3aed92e/sample/2c2022e404107f83e2ff379715f53b1f':
#  - Group: sample(e3f8b3bad86a5c17d16e20b3c3aed92e)
# Submitting cluster job 'Umbrella/43e20cc5e137ed62723446b8ff0a1d7a/sample/10b8df8f672f0aa08d3ba5f05ff9028b':
#  - Group: sample(43e20cc5e137ed62723446b8ff0a1d7a)
# Submitting cluster job 'Umbrella/bec1d6968893d6e5de2ed3fdbd942a05/sample/58dea243e5166f66f4908b88f7932556':
#  - Group: sample(bec1d6968893d6e5de2ed3fdbd942a05)
# Submitting cluster job 'Umbrella/b07d7bbe9aaebef9e50c85a59ea26876/sample/23c373aa3b5353e118fccc8ad0f00879':
#  - Group: sample(b07d7bbe9aaebef9e50c85a59ea26876)
# Submitting cluster job 'Umbrella/b53b12dad808c4c9058b63eaf0a98834/sample/76ad1541e4c35018bf1971a0126f6c6e':
#  - Group: sample(b53b12dad808c4c9058b63eaf0a98834)
# Submitting cluster job 'Umbrella/ed80aee1d03abf511b6671ecb872765a/sample/cdae234a46bd58d059a22a3c290cd3bc':
#  - Group: sample(ed80aee1d03abf511b6671ecb872765a)
# Submitting cluster job 'Umbrella/62c2f98e187c3782a2a225536b6862cd/sample/5e510c67e0fbad4ed7fc99366c4c8510':
#  - Group: sample(62c2f98e187c3782a2a225536b6862cd)
# Submitting cluster job 'Umbrella/ed39ff63128cf8d5059a4d5c0b33f059/sample/2cb00f008f313054e627a56640ef5e54':
#  - Group: sample(ed39ff63128cf8d5059a4d5c0b33f059)
# Submitting cluster job 'Umbrella/a0b643e507f6c7e41f3e3cb1e0c978e2/sample/d72807735202843e406b581e0991543e':
#  - Group: sample(a0b643e507f6c7e41f3e3cb1e0c978e2)
# Submitting cluster job 'Umbrella/21a429f662bb1ccd35ad0f048ef5db78/sample/6a122864b877d03a0d0628bf0bf95d23':
#  - Group: sample(21a429f662bb1ccd35ad0f048ef5db78)
# Submitting cluster job 'Umbrella/1e4dce5f51ce053ab90c225fcf997fe7/sample/504173861226073f922c2297aa8ca81c':
#  - Group: sample(1e4dce5f51ce053ab90c225fcf997fe7)
# Submitting cluster job 'Umbrella/24f66f7ba98ee153edc65d67c735a75a/sample/d3418b929202683c0b51f6f34b2a540d':
#  - Group: sample(24f66f7ba98ee153edc65d67c735a75a)
# Submitting cluster job 'Umbrella/0a7c9272a309fd1eac3e3a59e7f094f0/sample/666f4cf53cd4c5b8aa970398b1369f8c':
#  - Group: sample(0a7c9272a309fd1eac3e3a59e7f094f0)
# Submitting cluster job 'Umbrella/f09b226fc3d68945ea9bec5e4399a865/sample/02d852cb346039fac5d7bacaa3ca21b2':
#  - Group: sample(f09b226fc3d68945ea9bec5e4399a865)
# Submitting cluster job 'Umbrella/76f7cb6430b205f7bf3e3b3cab0e75f6/sample/9bb91364101b1e6f23e411fc8532cd99':
#  - Group: sample(76f7cb6430b205f7bf3e3b3cab0e75f6)
# Submitting cluster job 'Umbrella/b52f52904e848638112494459e5b3798/sample/9585663d1c49e237a9c004c261784281':
#  - Group: sample(b52f52904e848638112494459e5b3798)
# Submitting cluster job 'Umbrella/9ae279a29a1e1783a41b3265e909323e/sample/e1288d15a8f8a2d0ed080e12a2e5fc06':
#  - Group: sample(9ae279a29a1e1783a41b3265e909323e)
# Submitting cluster job 'Umbrella/fb205c658618192bfd105ca3dbe35267/sample/d156d55ce7a83d9d2ffa212e30534757':
#  - Group: sample(fb205c658618192bfd105ca3dbe35267)
# Submitting cluster job 'Umbrella/f455e1e1f0a1ce2c3fab5b1775dded43/sample/cd7f43f4346f1f98563f565fb9b55fb8':
#  - Group: sample(f455e1e1f0a1ce2c3fab5b1775dded43)
# Submitting cluster job 'Umbrella/2cf1462a07d613d2a4aa45ca64d20a0d/sample/4e81f5906597004172a3ccb1bd6ec1a5':
#  - Group: sample(2cf1462a07d613d2a4aa45ca64d20a0d)
# Submitting cluster job 'Umbrella/f2f643cebe0cb18c5dd528483006e666/sample/54ee548f446bf7766e437442ca6257ba':
#  - Group: sample(f2f643cebe0cb18c5dd528483006e666)
# Submitting cluster job 'Umbrella/d3c41bc6746f21a8b86ac81af4ab80fb/sample/fce8ed7eca5c7b2d79348ba72481fb66':
#  - Group: sample(d3c41bc6746f21a8b86ac81af4ab80fb)
# Submitting cluster job 'Umbrella/4f6e6aa7f56466a12ee8fbc37b36faf4/sample/578f67c698af7172ab04e98a5d17b5a5':
#  - Group: sample(4f6e6aa7f56466a12ee8fbc37b36faf4)
# Submitting cluster job 'Umbrella/13779f0c904fc7cae89b2c35892bdac2/sample/4bbe9bae044b58b38c88f240b82df690':
#  - Group: sample(13779f0c904fc7cae89b2c35892bdac2)
# Submitting cluster job 'Umbrella/e053819fba08ce5410eeeb7d11945d3a/sample/bc21b3c829d4f0962922f6960fdf803a':
#  - Group: sample(e053819fba08ce5410eeeb7d11945d3a)
# Submitting cluster job 'Umbrella/3ff740726bb1a652dddcd1263c0c270f/sample/d2b09ae298ef643659257026dfcec1ef':
#  - Group: sample(3ff740726bb1a652dddcd1263c0c270f)
# Submitting cluster job 'Umbrella/5d603cec72f9fa42d961437be08975e2/sample/abf842c961fa161920f78715cbfb6ad6':
#  - Group: sample(5d603cec72f9fa42d961437be08975e2)
# Submitting cluster job 'Umbrella/15e53f5b21243e8ccea7f2b66a05b4a2/sample/c1dc48d064265d38bd4b1c2fb4ce428a':
#  - Group: sample(15e53f5b21243e8ccea7f2b66a05b4a2)
# Submitting cluster job 'Umbrella/e14741f1bf2b462c41adb5947c49a3e9/sample/00f8e6fecf6efad2ba934af27a61e0c3':
#  - Group: sample(e14741f1bf2b462c41adb5947c49a3e9)
# Submitting cluster job 'Umbrella/16b0c40782b1b81ab8155659f367fed0/sample/37199836bffb78a2ca833205cfccb785':
#  - Group: sample(16b0c40782b1b81ab8155659f367fed0)
# Querying scheduler...
# Submitting cluster job 'Umbrella/e29921e5df2ad751e3fa9a5aad55a8cd/sample/a0d24ef93efe12f8d972400a03de75b1':
#  - Group: sample(e29921e5df2ad751e3fa9a5aad55a8cd)
# Submitting cluster job 'Umbrella/4e61625554859082c6757dec0d147ce1/sample/13cf735054776b132c72704b284abe54':
#  - Group: sample(4e61625554859082c6757dec0d147ce1)
# Submitting cluster job 'Umbrella/cb951a44422f22ae31d0699d59686739/sample/77be7a4fa2d8cf559cacabd028e3272a':
#  - Group: sample(cb951a44422f22ae31d0699d59686739)
# Submitting cluster job 'Umbrella/ca429de34c0bc815417abdc63f28a71e/sample/4d23f7e6713b353f8caa0187e00c0aaa':
#  - Group: sample(ca429de34c0bc815417abdc63f28a71e)
# Submitting cluster job 'Umbrella/4f9b1f378d0984373f5983c997609f5a/sample/a854feddcf6c54d2f7432b55447cc10d':
#  - Group: sample(4f9b1f378d0984373f5983c997609f5a)
# Submitting cluster job 'Umbrella/62c44a83318b3e271af6388072bdc131/sample/0f05c44f6f53629e3011b55b78540319':
#  - Group: sample(62c44a83318b3e271af6388072bdc131)
# Submitting cluster job 'Umbrella/9e641d65a2697020ea10dd603e17eca5/sample/a1a3fb3a637af84e45ced69b25b8096a':
#  - Group: sample(9e641d65a2697020ea10dd603e17eca5)
# Submitting cluster job 'Umbrella/d869cf72da825e570ae44b8635403ce4/sample/e7ef3565a8cd0a1f900374dd31a9991f':
#  - Group: sample(d869cf72da825e570ae44b8635403ce4)
# Submitting cluster job 'Umbrella/b3746408ff2ffb9f7a80306bc91ac02a/sample/a2fbd8d4a648d6861f7871fdc5e67da0':
#  - Group: sample(b3746408ff2ffb9f7a80306bc91ac02a)
# Submitting cluster job 'Umbrella/7c8e959eb1118ef9e0b174a63481c470/sample/333259562065407c4a359adc1ad643e0':
#  - Group: sample(7c8e959eb1118ef9e0b174a63481c470)
# Submitting cluster job 'Umbrella/f83402762bdd71f01122a66bc3bf0c75/sample/8fff7bf0533cc857f6a1fcfc9160477e':
#  - Group: sample(f83402762bdd71f01122a66bc3bf0c75)
# Submitting cluster job 'Umbrella/924c1496abdd91444ac5561d9c9827ee/sample/ec4f22a6803e5b216e21cfed8be11e99':
#  - Group: sample(924c1496abdd91444ac5561d9c9827ee)
# Submitting cluster job 'Umbrella/6d80b3dc4507ef18f5ce72858d05d575/sample/06866b616aa7be26d74557ae62ab8366':
#  - Group: sample(6d80b3dc4507ef18f5ce72858d05d575)
# Submitting cluster job 'Umbrella/19698fb48c46a103e29e33e7a2257fe6/sample/be3a2038d320c1f27b56edce240013ba':
#  - Group: sample(19698fb48c46a103e29e33e7a2257fe6)
# Submitting cluster job 'Umbrella/84050a69c532710c04951b3d6d0d10a8/sample/97a6dd916ac9cdb9cb32c9d072e5ede3':
#  - Group: sample(84050a69c532710c04951b3d6d0d10a8)
# Submitting cluster job 'Umbrella/9b9604b40c270218b4aecc3393f1c253/sample/ab1bba8d219aad6e1e394ab1badec515':
#  - Group: sample(9b9604b40c270218b4aecc3393f1c253)
# Submitting cluster job 'Umbrella/3c6493fb87379e462b615cdb731dbd5f/sample/3a65baa2296b8351639653c9a3e23fe9':
#  - Group: sample(3c6493fb87379e462b615cdb731dbd5f)
#  - Group: sample(bec1d6968893d6e5de2ed3fdbd942a05)
# Submitting cluster job 'Umbrella/b07d7bbe9aaebef9e50c85a59ea26876/sample/f9d60ecb3e2f48b823ee2cf1b5e87ed2':
#  - Group: sample(b07d7bbe9aaebef9e50c85a59ea26876)
# Submitting cluster job 'Umbrella/b53b12dad808c4c9058b63eaf0a98834/sample/a1fc830097e627242bbb8c1aa080219e':
#  - Group: sample(b53b12dad808c4c9058b63eaf0a98834)
# Submitting cluster job 'Umbrella/ed80aee1d03abf511b6671ecb872765a/sample/7eecde1fd69e9f564638b5a1b735a99a':
#  - Group: sample(ed80aee1d03abf511b6671ecb872765a)
# Submitting cluster job 'Umbrella/62c2f98e187c3782a2a225536b6862cd/sample/049b852dd7e8803f24a29813c88be4b4':
#  - Group: sample(62c2f98e187c3782a2a225536b6862cd)
# Submitting cluster job 'Umbrella/ed39ff63128cf8d5059a4d5c0b33f059/sample/6bc9545fd04a1a5ec6c784a5dbb95949':
#  - Group: sample(ed39ff63128cf8d5059a4d5c0b33f059)
# Submitting cluster job 'Umbrella/a0b643e507f6c7e41f3e3cb1e0c978e2/sample/89e2ff7295791558aa2fa567692eb2ed':
#  - Group: sample(a0b643e507f6c7e41f3e3cb1e0c978e2)
# Submitting cluster job 'Umbrella/21a429f662bb1ccd35ad0f048ef5db78/sample/bd796aef66980ba622df582a4ba106f1':
#  - Group: sample(21a429f662bb1ccd35ad0f048ef5db78)
# Submitting cluster job 'Umbrella/1e4dce5f51ce053ab90c225fcf997fe7/sample/c91723071715e51d4eae7c5c1e1fe622':
#  - Group: sample(1e4dce5f51ce053ab90c225fcf997fe7)
# Submitting cluster job 'Umbrella/24f66f7ba98ee153edc65d67c735a75a/sample/a1dbc18b67ff68ca54819b9b60b0c7c8':
#  - Group: sample(24f66f7ba98ee153edc65d67c735a75a)
# Submitting cluster job 'Umbrella/0a7c9272a309fd1eac3e3a59e7f094f0/sample/3528e673209b768d4377e7555da3f6a4':
#  - Group: sample(0a7c9272a309fd1eac3e3a59e7f094f0)
# Submitting cluster job 'Umbrella/f09b226fc3d68945ea9bec5e4399a865/sample/d99fd7fdf627067ae2847039e2dbbbc7':
#  - Group: sample(f09b226fc3d68945ea9bec5e4399a865)
# Submitting cluster job 'Umbrella/76f7cb6430b205f7bf3e3b3cab0e75f6/sample/1351e7b564d3efd6b2541f21ee3d52db':
#  - Group: sample(76f7cb6430b205f7bf3e3b3cab0e75f6)
# Submitting cluster job 'Umbrella/b52f52904e848638112494459e5b3798/sample/c137a16bc6adc02aa3791456c7d37053':
#  - Group: sample(b52f52904e848638112494459e5b3798)
# Submitting cluster job 'Umbrella/9ae279a29a1e1783a41b3265e909323e/sample/f817818fd252529d66733b7f8882781d':
#  - Group: sample(9ae279a29a1e1783a41b3265e909323e)
# Submitting cluster job 'Umbrella/fb205c658618192bfd105ca3dbe35267/sample/19220656c440a08e9f068eb89e21a66e':
#  - Group: sample(fb205c658618192bfd105ca3dbe35267)
# Submitting cluster job 'Umbrella/f455e1e1f0a1ce2c3fab5b1775dded43/sample/cf1dbbb17a2a9e543726768ba2dcb2c5':
#  - Group: sample(f455e1e1f0a1ce2c3fab5b1775dded43)
# Submitting cluster job 'Umbrella/2cf1462a07d613d2a4aa45ca64d20a0d/sample/f84757d2199b9cc353bd6c68af48b56c':
#  - Group: sample(2cf1462a07d613d2a4aa45ca64d20a0d)
# Submitting cluster job 'Umbrella/f2f643cebe0cb18c5dd528483006e666/sample/61f0a968cb06ceee77dd8a99125f0622':
#  - Group: sample(f2f643cebe0cb18c5dd528483006e666)
# Submitting cluster job 'Umbrella/d3c41bc6746f21a8b86ac81af4ab80fb/sample/a3ec4d713964725b0b76753bbfbb5810':
#  - Group: sample(d3c41bc6746f21a8b86ac81af4ab80fb)
# Submitting cluster job 'Umbrella/4f6e6aa7f56466a12ee8fbc37b36faf4/sample/dced415992fdfbae4fc49697aae35a4e':
#  - Group: sample(4f6e6aa7f56466a12ee8fbc37b36faf4)
# Submitting cluster job 'Umbrella/13779f0c904fc7cae89b2c35892bdac2/sample/60db5fbee1b4105225a69ff880cbe00a':
#  - Group: sample(13779f0c904fc7cae89b2c35892bdac2)
# Submitting cluster job 'Umbrella/e053819fba08ce5410eeeb7d11945d3a/sample/8006514ec017128dd7c9a4a2d29b0d52':
#  - Group: sample(e053819fba08ce5410eeeb7d11945d3a)
# Submitting cluster job 'Umbrella/3ff740726bb1a652dddcd1263c0c270f/sample/2e6cd297b437ebab84e03fe189ad4a54':
#  - Group: sample(3ff740726bb1a652dddcd1263c0c270f)
# Submitting cluster job 'Umbrella/5d603cec72f9fa42d961437be08975e2/sample/089fb827c9a8ee1b1f5f203afbb514a6':
#  - Group: sample(5d603cec72f9fa42d961437be08975e2)
# Submitting cluster job 'Umbrella/15e53f5b21243e8ccea7f2b66a05b4a2/sample/5feff2a3c162f301437634a894a63899':
#  - Group: sample(15e53f5b21243e8ccea7f2b66a05b4a2)
# Submitting cluster job 'Umbrella/e14741f1bf2b462c41adb5947c49a3e9/sample/7a63aa31af38d89496e0fd30d5b204e3':
#  - Group: sample(e14741f1bf2b462c41adb5947c49a3e9)
# Submitting cluster job 'Umbrella/16b0c40782b1b81ab8155659f367fed0/sample/372947f30c07813a22961965c47f620c':
#  - Group: sample(16b0c40782b1b81ab8155659f367fed0)

# %%
import signac
import gsd.hoomd
import matplotlib.pyplot as plt

project = signac.get_project("Solid")
for job in project:
    if job.sp.pf > compute_pf_mn - 1e-3 and job.sp.pf < compute_pf_mx + 1e-3:
        proj = signac.get_project(job.path+'/Umbrella')
        timeseries_paths = []
        windows = []
        ks = []
        for subjob in proj:
            timeseries_paths.append(subjob.path+f'/window_{subjob.sp.window:.3f}.dat')
            windows.append(subjob.sp.window)
            ks.append(subjob.sp.k)
        with open(job.path+'/Umbrella/metadata.txt', 'w') as f:
            f.write('# timeseries list for wham\n')
            for path,window,k in zip(timeseries_paths,windows,ks):
                f.write(path+' '+str(window)+' '+str(k)+'\n')
        hist_left = min(windows) - (max(windows)-min(windows))/10
        hist_right = max(windows) + (max(windows)-min(windows))/10
        num_hist = 100
        tolerance = 1e-5
        temperature = 1
        metafilename = job.path+'/Umbrella/metadata.txt'
        outfilename = job.path + '/Umbrella/pmf.out'
        print(f'wham {hist_left} {hist_right} {num_hist} {tolerance} {temperature} 0 {metafilename} {outfilename}')

# %%
import numpy as np
import matplotlib.pyplot as plt
import signac
from matplotlib.colors import Normalize
project = signac.get_project("Solid")
datas = dict()
plt.figure(figsize=(8, 5), dpi=150)  # 设置图像大小和分辨率
for job in project:
    if job.sp.pf > compute_pf_mn - 1e-3 and job.sp.pf < compute_pf_mx + 1e-3:
        data = np.loadtxt(job.path+"/Umbrella/pmf.out", comments="#")  # 跳过以 # 开头的注释行
        x = data[:, 0]  # 反应坐标（单位：Å）
        free_energy = data[:, 1]  # 自由能（单位：kcal/mol）
        datas[job.sp.pf] = [x,free_energy]
        
pfs = np.array(sorted(datas.keys()))
datas = np.array([datas[pf] for pf in pfs])
cmap = plt.get_cmap('plasma')
norm = Normalize(vmin=min(pfs), vmax=max(pfs))
colors = [cmap(norm(v)) for v in pfs]
for i in range(len(datas)):
    x = datas[i][0]
    free_energy = datas[i][1]
    plt.plot(
        x,
        free_energy/400,
        color=colors[i],
        linewidth=2,
        # marker="o",
        markersize=5,
        label=f"{pfs[i]:.2f}",
        alpha = 0.8
    )

    # if data.shape[1] >= 3:
    #     error = data[:, 2]  # 第2列是自由能误差
    #     plt.fill_between(
    #         x,
    #         free_energy - error,
    #         free_energy + error,
    #         alpha=0.3,
    #         color="skyblue",
    #         label="Error",
    #     )

    # 设置坐标轴
    plt.xlabel("Reaction Coordinate", fontsize=12)
    plt.ylabel(r"$F/(Nk_BT)$", fontsize=12)
    plt.title("Free Energy", fontsize=14)

    # plt.xlim(x.min() - 0.5, x.max() + 0.5)
    # plt.ylim(
    #     np.floor(-0.1),
    #     np.ceil(free_energy.max() + 1),
    # )

    # 添加辅助元素
    plt.grid(alpha=0.3, linestyle="--")  # 半透明虚线网格
    plt.legend(frameon=False)  # 无边框图例
    # plt.show()
    # # 保存图像（支持PDF/PNG/SVG等格式）
    # plt.savefig("pmf_plot.png", bbox_inches="tight", dpi=300)

# %% [markdown]
# # 四、收菜

# %% [markdown]
# ### 压强图

# %%
import signac
import matplotlib.pyplot as plt
import numpy as np

# project = signac.get_project("Fluid")
# fluid = dict()
# fluid_err = dict()
# for job in project:
#     if "Pressure" in job.document:
#         fluid[job.doc.packing_fraction] = float(job.doc["Pressure"].split()[0])
#         fluid_err[job.doc.packing_fraction] = float(job.doc["Pressure"].split()[2])
# pfs = np.array(sorted(fluid.keys()))
# fluid = np.array([fluid[pf] for pf in pfs])
# fluid_err = np.array([fluid_err[pf] for pf in pfs])
# plt.errorbar(pfs,fluid,yerr=fluid_err,marker='.',label="Fluid")

project = signac.get_project("Solid")
solid = dict()
solid_err = dict()
for job in project:
    if "Pressure" in job.document:
        solid[job.sp.pf] = float(job.doc["Pressure"].split()[0])
        solid_err[job.sp.pf] = float(job.doc["Pressure"].split()[2])
pfs = np.array(sorted(solid.keys()))
solid = np.array([solid[pf] for pf in pfs])
solid_err = np.array([solid_err[pf] for pf in pfs])
plt.errorbar(pfs,solid,yerr=solid_err,marker='.',label="Solid")

plt.xlabel("Packing fraction")
plt.xlim(0,1.02)
plt.ylabel("Pressure")
plt.ylim(0,60)
plt.legend()
plt.savefig("Pressure.png")

# %% [markdown]
# ### 可视化样品提取

# %%
import signac
import matplotlib.pyplot as plt
import numpy as np
import os
import shutil
project = signac.get_project("Solid")
data = os.getcwd() + '/Solid/visualization'
try:
    os.mkdir(data)
except:
    pass
for job in project:
    if "Pressure" in job.document:
        src = job.fn('equilibrium.gsd')
        dst = data + f'/{job.sp.pf:.3f}.gsd'
        shutil.copy(src, dst)
        print(f'{job.sp.pf:.3f} Done')
# Out:
# 0.690 Done
# 0.620 Done
# 0.650 Done
# 0.660 Done
# 0.530 Done
# 0.680 Done
# 0.580 Done
# 0.500 Done
# 0.600 Done
# 0.630 Done
# 0.670 Done
# 0.610 Done
# 0.560 Done
# 0.640 Done
# 0.510 Done
# 0.520 Done
# 0.590 Done
# 0.570 Done
# 0.550 Done
# 0.540 Done

# %% [markdown]
# ### 检测晶格畸变

# %%
import signac
import matplotlib.pyplot as plt
import numpy as np
import gsd.hoomd

# try:
project = signac.get_project("Solid")
box = dict()
box_err = dict()
solid = dict()
solid_err = dict()
for job in project:
    if "Pressure" in job.document:
        with gsd.hoomd.open(job.fn("equilibrium.gsd")) as f:
            temp = []
            for i in range(len(f) // 2):
                temp.append(f[-1 - i].configuration.box)
            box[job.sp.pf] = np.mean(temp, axis=0)
            box_err[job.sp.pf] = np.std(temp, axis=0)
        solid[job.sp.pf] = float(job.doc["Pressure"].split()[0])
        solid_err[job.sp.pf] = float(job.doc["Pressure"].split()[2])
pfs = np.array(sorted(solid.keys()))
solid = np.array([solid[pf] for pf in pfs])
solid_err = np.array([solid_err[pf] for pf in pfs])
box = np.array([box[pf] for pf in pfs])
box_err = np.array([box_err[pf] for pf in pfs])


# plt.figure()

# plt.plot([0.715,0.715],[0,60],color='black',linestyle="--")
# plt.ylim(7,9)
# plt.legend()

# 创建图形和第一个 y 轴
# 创建带分隔线的上下子图
fig, (ax1, ax2) = plt.subplots(
    2,
    1,
    figsize=(8, 8),
    sharex=True,
    gridspec_kw={"height_ratios": [1, 1], "hspace": 0},
    facecolor="white",
)

# 绘制第一组数据
# ax1.errorbar(pfs, box[:,3],box_err[:, 3], label="xy")
# ax1.errorbar(pfs, box[:,4],box_err[:, 4], label="xz")
# ax1.errorbar(pfs, box[:,5],box_err[:, 5], label="yz")
ax1.errorbar(
    pfs, box[:, 0] * pfs ** (1 / 3), box_err[:, 0] * pfs ** (1 / 3), label="Lx"
)
ax1.errorbar(
    pfs, box[:, 1] * pfs ** (1 / 3), box_err[:, 1] * pfs ** (1 / 3), label="Ly"
)
ax1.errorbar(
    pfs, box[:, 2] * pfs ** (1 / 3), box_err[:, 2] * pfs ** (1 / 3), label="Lz"
)
# ax1.plot([0.72,0.72],[-60,60],'--',color='black')
# ax1.plot([0.64,0.64],[-60,60],'--',color='black')
# ax1.set_ylim(-0.1 + 1e-6, 0.7)

ax1.set_xlabel("packing fraction")
ax1.set_ylabel("BoxTilt")
ax1.tick_params(axis="y")
ax1.legend()

ax2.errorbar(pfs, solid, yerr=solid_err, marker=".", label=r"$F432(1.65,2,2.285)$")
ax2.set_ylabel("Pressure")
# # 绘制第二组数据
# ax2.plot(pfs, box[:, 0] * pfs ** (1 / 3), label="Lx")
# ax2.plot(pfs, box[:, 1] * pfs ** (1 / 3), label="Ly")
# ax2.plot(pfs, box[:, 2] * pfs ** (1 / 3), label="Lz")
# # ax2.plot([0.72,0.72],[-60,60],'--',color='black')
# # ax2.plot([0.64,0.64],[-60,60],'--',color='black')
# # ax2.set_ylim(7.5, 15 - 1e-6)
# ax2.set_ylabel("BoxL")
# ax2.tick_params(axis="y")
# ax2.legend()

plt.show()
fig.savefig("box_tilt.png")

# %% [markdown]
# ### 自由能图

# %%
import signac
import matplotlib.pyplot as plt
import numpy as np

project = signac.get_project("Fluid")
fluid = dict()
fluid_err = dict()
for job in project:
    if "free_energy" in job.document:
        fluid[job.doc.packing_fraction] = float(job.doc["free_energy"].split()[0])
        fluid_err[job.doc.packing_fraction] = float(job.doc["free_energy"].split()[2])
pfs = np.array(sorted(fluid.keys()))
fluid = np.array([fluid[pf] for pf in pfs])
fluid_err = np.array([fluid_err[pf] for pf in pfs])
plt.errorbar(pfs,fluid,yerr=fluid_err,marker='.',label="Fluid")

project = signac.get_project("Solid")
solid = dict()
solid_err = dict()
for job in project:
    if "free_energy" in job.document:
        solid[job.sp.pf] = float(job.doc["free_energy"].split()[0])
        solid_err[job.sp.pf] = float(job.doc["free_energy"].split()[2])
pfs = np.array(sorted(solid.keys()))
solid = np.array([solid[pf] for pf in pfs])
solid_err = np.array([solid_err[pf] for pf in pfs])
plt.errorbar(pfs,solid,yerr=solid_err,marker='.',label="Solid")

plt.xlabel("Packing fraction")
plt.xlim(0,1.02)
plt.ylabel("Free Energy")
plt.ylim(0,20)
plt.legend()
plt.savefig("FreeEnergy.png")

# %% [markdown]
# ### 打包所有数据(谨慎)

# %%
import os
import shutil
def ignore_exceptions_execute(code_lines):
    for line in code_lines:
        try:
            # 使用 exec 执行单行代码
            exec(line)
        except Exception as e:
            # 可以选择打印或记录异常信息
            print(f"Ignored exception in line '{line}': {str(e)}")
            continue
data_directory = os.getcwd() + "/s=0.4"
initstr = "Densest[F432(1.00,2,2.20)] : DSC"
with open("information.txt", "w") as f:
    f.write("--------------------------------\n\n")
    f.write(f"particle factory:{factorystr}\n\n")
    f.write(f"initialization:{initstr}\n\n")
    
code_lines = [
    "os.mkdir(data_directory)",
    "shutil.move('DensestProject', data_directory)",
    "shutil.move('information.txt', data_directory)",
    "shutil.move('Pressure.png', data_directory)",
    "shutil.move('box_tilt.png', data_directory)",
    "shutil.move('FreeEnergy.png', data_directory)",
    "shutil.move('Fluid', data_directory)",
    "shutil.move('Solid', data_directory)",
    "shutil.move('sample0.gsd', data_directory)"
]
ignore_exceptions_execute(code_lines)
print('Done!')
# Out:
# '/home/jwang/HOOMD_HPMC/amazing_v2_test/test1_2.286_in_BCC/sample0.gsd'
